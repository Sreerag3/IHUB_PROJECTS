# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreerag3/IHUB_PROJECTS/blob/main/Telangana%20Vehicle%20no%20bsed%20classifiactaion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the data from the CSV file
data = pd.read_csv('/content/Updated Roster.csv')

# Select relevant columns
data = data[['SERVICE No.', 'OPTD_ KMS', 'VEHICLE No.', 'Corridor']]

# Group by 'VEHICLE No.' and aggregate the 'OPTD_ KMS', 'SERVICE No.', and 'Corridor'
aggregated_data = data.groupby('VEHICLE No.').agg({'OPTD_ KMS': 'sum', 'SERVICE No.': 'unique', 'Corridor': 'unique'}).reset_index()

# Iterate through the rows and print unique SERVICE No., Corridor, and aggregated OPTD_ KMS
for index, row in aggregated_data.iterrows():
    vehicle_no = row['VEHICLE No.']
    total_optd_kms = row['OPTD_ KMS']
    unique_service_numbers = row['SERVICE No.']
    unique_corridors = row['Corridor']

    print(f"Vehicle No.: {vehicle_no}")
    print(f"Total OPTD_ KMS: {total_optd_kms}")
    print(f"Unique SERVICE No.: {unique_service_numbers}")
    print(f"Unique Corridors: {unique_corridors}")
    print("===")

# Save the result to an Excel file
aggregated_data.to_excel("Veh No based ride details.xlsx", index=False)
# Out:
# Vehicle No.: AP28Z0811
# Total OPTD_ KMS: 900.0
# Unique SERVICE No.: [9011]
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS05Z0171
# Total OPTD_ KMS: 14810.0
# Unique SERVICE No.: [3062 1712 1832 2942 2922 2852 2882 1652 2832 2912 3042 2982 2972 2962
#  3022 2862 3012]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4006
# Total OPTD_ KMS: 12120.0
# Unique SERVICE No.: [2722 3052 2612 2982 2622 2702 2642 2652 2732 2632 3022 2782 2662 2792]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4070
# Total OPTD_ KMS: 13884.0
# Unique SERVICE No.: [3032 2872 3002 1642 1622 2932 2942 3052 2992 2962 9507]
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4071
# Total OPTD_ KMS: 15652.0
# Unique SERVICE No.: [1632 2872 3032 3002 1652 2842]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4072
# Total OPTD_ KMS: 12168.0
# Unique SERVICE No.: [1622 1732 2842 1632 3002 2872 3032 2982 2852 1712]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4073
# Total OPTD_ KMS: 11056.0
# Unique SERVICE No.: [2842 1622 2852 2872 1732 1632 3032]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4074
# Total OPTD_ KMS: 15178.0
# Unique SERVICE No.: [3002 2872 1642 1622 9507 1632 3032]
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4089
# Total OPTD_ KMS: 13414.0
# Unique SERVICE No.: [1622 2912 2842 1632 2942 1642 9051 2872 3032]
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4111
# Total OPTD_ KMS: 1244.0
# Unique SERVICE No.: [2872 3002 1622]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0028
# Total OPTD_ KMS: 3612.0
# Unique SERVICE No.: [2632 2982 1732 2622 2952]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0052
# Total OPTD_ KMS: 10836.0
# Unique SERVICE No.: [2652 2782 2662 2952 2632 2622 3012 2792 2922 2942 2962 2722 2982]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0201
# Total OPTD_ KMS: 12130.0
# Unique SERVICE No.: [2592 2712 2652 2732 9038 2942 2952 2642 2782]
# Unique Corridors: ['Others' 'Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0202
# Total OPTD_ KMS: 14928.0
# Unique SERVICE No.: [2582 2652 2792 2732]
# Unique Corridors: ['Others' 'Vijayawada']
# ===
# Vehicle No.: TS15Z0203
# Total OPTD_ KMS: 14057.0
# Unique SERVICE No.: [1752 2572 2782 9038 2642 2792 2652]
# Unique Corridors: ['Vijayawada' 'Others' nan]
# ===
# Vehicle No.: TS15Z0211
# Total OPTD_ KMS: 14110.0
# Unique SERVICE No.: [2592 2572 2712 2652 2662]
# Unique Corridors: ['Others' 'Vijayawada']
# ===
# Vehicle No.: TS15Z0218
# Total OPTD_ KMS: 13302.0
# Unique SERVICE No.: [2592 2582]
# Unique Corridors: ['Others']
# ===
# Vehicle No.: TS15Z0221
# Total OPTD_ KMS: 12413.0
# Unique SERVICE No.: [2982 2642 2712 2652 2792 9037 9038 2732 2702 2662 2722]
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0223
# Total OPTD_ KMS: 11234.0
# Unique SERVICE No.: [2622 2712 9038 2572 2732 1712 1642 2952 3022 3042 2612 2982 1732 2632]
# Unique Corridors: ['Vijayawada' nan 'Others']
# ===
# Vehicle No.: TS15Z0224
# Total OPTD_ KMS: 11026.0
# Unique SERVICE No.: [2622 2632 1712 2652 2832 3052 9506 2662 1752 2952]
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0228
# Total OPTD_ KMS: 5717.0
# Unique SERVICE No.: [1832 9038 9037 2792 2572]
# Unique Corridors: ['Vijayawada' nan 'Others']
# ===
# Vehicle No.: TS15Z0229
# Total OPTD_ KMS: 5399.0
# Unique SERVICE No.: [1622 9039 2712 2582]
# Unique Corridors: ['Vijayawada' nan 'Others']
# ===
# Vehicle No.: TS15Z0230
# Total OPTD_ KMS: 5576.0
# Unique SERVICE No.: [1712 2712]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS15Z0231
# Total OPTD_ KMS: 7404.0
# Unique SERVICE No.: [2952 2972 2622 2652 2782 2732 2642]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS15Z0232
# Total OPTD_ KMS: 6062.0
# Unique SERVICE No.: [2592 9037 2632 2982 3052 2722 2932 2792 2622 2612]
# Unique Corridors: ['Others' nan 'Vijayawada']
# ===
# Vehicle No.: TS18Z0032
# Total OPTD_ KMS: 60.0
# Unique SERVICE No.: [2612]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS18Z0033
# Total OPTD_ KMS: 3612.0
# Unique SERVICE No.: [2612 2632 3042 2782 2652 2702]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS22Z0037
# Total OPTD_ KMS: 12040.0
# Unique SERVICE No.: [2982 1732 2632 2622 2842 2792 2782 2722 2942 2702 2642 2612]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS36Z0010
# Total OPTD_ KMS: 12808.0
# Unique SERVICE No.: [2662 2952 2632 2622 2712 2722 2702 2642 2792 2942 2612 3042 2972]
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS36Z0013
# Total OPTD_ KMS: 1806.0
# Unique SERVICE No.: [2702 2622]
# Unique Corridors: ['Vijayawada']
# ===
