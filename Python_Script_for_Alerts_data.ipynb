# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreerag3/IHUB_PROJECTS/blob/main/Python_Script_for_Alerts_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/1st July - 31st July 2023 .csv")
df.head()
# Out:
#     startDate startTime     endDate   endTime  VehicleNum     vehicleModel  \
# 0  01-07-2023  05:58:54  01-07-2023  06:22:28  MH40BG2596     Eicher 10.75
# 1  01-07-2023  05:29:48  01-07-2023  05:44:47  MH40BG2596     Eicher 10.75
# 2  01-07-2023  06:06:08  01-07-2023  06:35:20  MH40BG7476     Eicher 10.75
# 3  01-07-2023  06:14:58  01-07-2023  06:33:28  MH40BG1535  Tata LP09.6 BS3
# 4  01-07-2023  05:35:59  01-07-2023  05:45:49  MH40BG1535  Tata LP09.6 BS3
#
#              groupName              driverName  StartLatGPS  StartLongGPS  \
# 0  Hansa-Aapli-Red-Bus  Rakesh Nandlal Meshram    21.141287     79.079645
# 1  Hansa-Aapli-Red-Bus  Rakesh Nandlal Meshram    21.116420     79.019128
# 2  Hansa-Aapli-Red-Bus         Vivek Choudhari    21.116597     79.013303
# 3  Hansa-Aapli-Red-Bus          Vinod Dehankar    21.140105     79.092358
# 4  Hansa-Aapli-Red-Bus          Vinod Dehankar    21.116942     79.019998
#
# ...

# %%
# drop column 'sum_of_alerts' from df in place
df.drop('endTime', axis=1, inplace=True)

# %%
# df_columns = df.columns
print(df.columns)
# Out:
# Index(['startDate', 'startTime', 'endDate', 'VehicleNum', 'vehicleModel',
#        'groupName', 'driverName', 'StartLatGPS', 'StartLongGPS', 'EndLatGPS',
#        'EndLongGPS', 'startAddress', 'endAddress', 'distance', 'duration',
#        'fuelConsumed', 'fuelWasted', 'mileage', 'me_fcw_count', 'me_dfm_count',
#        'me_hmw_count', 'me_lldw_count', 'me_pcw_count', 'me_pdz_count',
#        'me_rldw_count', 'me_tao_count', 'me_twl_count', 'me_ufcw_count',
#        'freerun_count', 'hard_brake_count', 'hard_curve_count', 'idling_count',
#        'over_acceleration_count', 'speeding_count', 'stoppage_count',
#        'hard_curving_count', 'dms_tampering', 'lm_tao_count',
#        'dms_driver_drowsy_count', 'dms_driver_asleep_count',
#        'dms_driver_smoking_count', 'dms_driver_distracted_count',
#        'dms_driver_on_phone_count', 'dms_no_seat_belt_count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47716 entries, 0 to 47715
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   startDate                    47716 non-null  object
#  1   startTime                    47716 non-null  object
#  2   endDate                      47716 non-null  object
#  3   VehicleNum                   47716 non-null  object
#  4   vehicleModel                 47716 non-null  object
#  5   groupName                    47716 non-null  object
#  6   driverName                   39503 non-null  object
#  7   StartLatGPS                  47715 non-null  float64
#  8   StartLongGPS                 47715 non-null  float64
#  9   EndLatGPS                    47715 non-null  float64
#  10  EndLongGPS                   47715 non-null  float64
#  11  startAddress                 47714 non-null  object
# ...

# %%
grouped_datewise = df.groupby('startDate')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
       'me_fcw_count', 'me_dfm_count','me_hmw_count','me_lldw_count','me_pcw_count','me_pdz_count','me_rldw_count',
       'me_tao_count','me_twl_count','me_ufcw_count','freerun_count','hard_brake_count','idling_count','over_acceleration_count',
       'speeding_count','hard_curving_count','dms_driver_drowsy_count','dms_driver_asleep_count','dms_driver_smoking_count',
       'dms_driver_distracted_count','dms_driver_on_phone_count','dms_no_seat_belt_count'].sum()
# Mean = df.groupby('startDate')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].mean()
# Max = df.groupby('startDate')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].max()
# Min = df.groupby('startDate')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].min()
# Out:
# <ipython-input-7-777e5edd100f>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_datewise = df.groupby('startDate')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',

# %%
pd.set_option('display.max_rows', None)  # this will display all rows

# assuming the data is stored in a pandas DataFrame called 'df'
# print(grouped_datewise)
# print(Mean)
# print(Max)
# print(Min)

# %%
data_wise = grouped_datewise.to_csv('Datewise-Jun.csv')
# D_Mean = Mean.to_csv("D-Mean.csv")
# D_Max = Max.to_csv("D-Max.csv")
# D_Min = Min.to_csv("D-Min.csv")

# %%
grouped_vehiclewise = df.groupby('VehicleNum')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
       'me_fcw_count', 'me_dfm_count','me_hmw_count','me_lldw_count','me_pcw_count','me_pdz_count','me_rldw_count',
       'me_tao_count','me_twl_count','me_ufcw_count','freerun_count','hard_brake_count','idling_count','over_acceleration_count',
       'speeding_count','hard_curving_count','dms_driver_drowsy_count','dms_driver_asleep_count','dms_driver_smoking_count',
       'dms_driver_distracted_count','dms_driver_on_phone_count','dms_no_seat_belt_count'].sum()
# Mean_1 = df.groupby('VehicleNum')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].mean()
# Max_1 = df.groupby('VehicleNum')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].max()
# Min_1 = df.groupby('VehicleNum')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].min()
# Out:
# <ipython-input-10-6fd12c092368>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_vehiclewise = df.groupby('VehicleNum')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',

# %%
pd.set_option('display.max_rows', None)  # this will display all rows

# # assuming the data is stored in a pandas DataFrame called 'df'
# # print(grouped_vehiclewise)
# # print(Mean_1)
# # print(Max_1)
# # print(Min_1)

# %%
vehicle_wise = grouped_vehiclewise.to_csv("Vehiclewise-Jun.csv")
# V_Mean = Mean_1.to_csv("V-Mean.csv")
# V_Max = Max_1.to_csv("V-Max.csv")
# V_Min = Min_1.to_csv("V-Min.csv")

# %%
grouped_modelwise = df.groupby('vehicleModel')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
       'me_fcw_count', 'me_dfm_count','me_hmw_count','me_lldw_count','me_pcw_count','me_pdz_count','me_rldw_count',
       'me_tao_count','me_twl_count','me_ufcw_count','freerun_count','hard_brake_count','idling_count','over_acceleration_count',
       'speeding_count','hard_curving_count','dms_driver_drowsy_count','dms_driver_asleep_count','dms_driver_smoking_count',
       'dms_driver_distracted_count','dms_driver_on_phone_count','dms_no_seat_belt_count'].sum()
# Mean_2 = df.groupby('vehicleModel')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].mean()
# Max_2 = df.groupby('vehicleModel')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].max()
# Min_2 = df.groupby('vehicleModel')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].min()
# Out:
# <ipython-input-13-2c18dc7c8c01>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_modelwise = df.groupby('vehicleModel')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',

# %%
pd.set_option('display.max_rows', None)  # this will display all rows

# # assuming the data is stored in a pandas DataFrame called 'df'
# # print(grouped_modelwise)
# # print(Mean_2)
# # print(Max_2)
# # print(Min_2)

# %%
model_wise = grouped_modelwise.to_csv("Modelwise-Jun.csv")
# M_Mean = Mean_2.to_csv("M-Mean.csv")
# M_Max = Max_2.to_csv("M-Max.csv")
# M_Min = Min_2.to_csv("M-Min.csv")

# %%
grouped_depotwise = df.groupby('groupName')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
       'me_fcw_count', 'me_dfm_count','me_hmw_count','me_lldw_count','me_pcw_count','me_pdz_count','me_rldw_count',
       'me_tao_count','me_twl_count','me_ufcw_count','freerun_count','hard_brake_count','idling_count','over_acceleration_count',
       'speeding_count','hard_curving_count','dms_driver_drowsy_count','dms_driver_asleep_count','dms_driver_smoking_count',
       'dms_driver_distracted_count','dms_driver_on_phone_count','dms_no_seat_belt_count'].sum()
# Mean_3 = df.groupby('groupName')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].mean()
# Max_3 = df.groupby('groupName')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].max()
# Min_3 = df.groupby('groupName')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'idling_count', 'over_acceleration_count', 'speeding_count',
#        'stoppage_count', 'hard_curving_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'].min()
# Out:
# <ipython-input-16-60b70e06e82a>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_depotwise = df.groupby('groupName')['distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',

# %%
pd.set_option('display.max_rows', None)  # this will display all rows

# # assuming the data is stored in a pandas DataFrame called 'df'
# # print(grouped_depotwise)
# # print(Mean_3)
# # print(Max_3)
# # print(Min_3)

# %%
depot_wise = grouped_depotwise.to_csv("Depotwise-Jun.csv")
# Dpt_Mean = Mean_2.to_csv("Dpt-Mean.csv")
# Dpt_Max = Max_2.to_csv("Dpt-Max.csv")
# Dpt_Min = Min_2.to_csv("Dpt-Min.csv")
