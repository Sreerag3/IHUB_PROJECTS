# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreerag3/IHUB_PROJECTS/blob/main/Telangana%20Veh%20No.%20based%20Adas%20%26%20Non%20Adas%20classification%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the data from the CSV file
data = pd.read_csv('/content/oct all corridor.csv')

# Select relevant columns
data = data[['SERVICE', 'OPTD_ KMS', 'VEHICLE No.', 'Corridor']]

# Group by 'VEHICLE No.' and aggregate the 'OPTD_ KMS', 'SERVICE No.', and 'Corridor'
aggregated_data = data.groupby('VEHICLE No.').agg({'OPTD_ KMS': 'sum', 'SERVICE': 'unique', 'Corridor': 'unique'}).reset_index()

# Iterate through the rows and print unique SERVICE No., Corridor, and aggregated OPTD_ KMS
for index, row in aggregated_data.iterrows():
    vehicle_no = row['VEHICLE No.']
    total_optd_kms = row['OPTD_ KMS']
    unique_service_numbers = row['SERVICE']
    unique_corridors = row['Corridor']

    print(f"Vehicle No.: {vehicle_no}")
    print(f"Total OPTD_ KMS: {total_optd_kms}")
    print(f"Unique SERVICE: {unique_service_numbers}")
    print(f"Unique Corridors: {unique_corridors}")
    print("===")

# Save the result to an Excel file
aggregated_data.to_excel("Veh No based ride details.xlsx", index=False)

# Read the second Excel file with ADAS vehicle list
second_file = pd.read_csv('/content/Adas bus details.csv')

# Classify as ADAS or Non ADAS based on VEHICLE No. presence in the second Excel file
data['bus'] = data['VEHICLE No.'].apply(lambda x: 'ADAS' if x in second_file['Veh No'].values else 'Non ADAS')

# Separate data into ADAS and Non ADAS DataFrames
adas_data = data[data['bus'] == 'ADAS']
non_adas_data = data[data['bus'] == 'Non ADAS']

# Group by 'VEHICLE No.' and aggregate the 'OPTD_ KMS', 'SERVICE No.', and 'Corridor'
aggregated_data = adas_data.groupby('VEHICLE No.').agg({'OPTD_ KMS': 'sum', 'SERVICE': 'unique', 'Corridor': 'unique'}).reset_index()

# Iterate through the rows and print unique SERVICE No., Corridor, and aggregated OPTD_ KMS
for index, row in aggregated_data.iterrows():
    vehicle_no = row['VEHICLE No.']
    total_optd_kms = row['OPTD_ KMS']
    unique_service_numbers = row['SERVICE']
    unique_corridors = row['Corridor']

    print(f"Vehicle No.: {vehicle_no}")
    print(f"Total OPTD_ KMS: {total_optd_kms}")
    print(f"Unique SERVICE: {unique_service_numbers}")
    print(f"Unique Corridors: {unique_corridors}")
    print("===")

# Save the result to an Excel file
aggregated_data.to_excel("Adas aggregated.xlsx", index=False)

    # Group by 'VEHICLE No.' and aggregate the 'OPTD_ KMS', 'SERVICE No.', and 'Corridor'
aggregated_data = non_adas_data.groupby('VEHICLE No.').agg({'OPTD_ KMS': 'sum', 'SERVICE': 'unique', 'Corridor': 'unique'}).reset_index()

# Iterate through the rows and print unique SERVICE No., Corridor, and aggregated OPTD_ KMS
for index, row in aggregated_data.iterrows():
    vehicle_no = row['VEHICLE No.']
    total_optd_kms = row['OPTD_ KMS']
    unique_service_numbers = row['SERVICE']
    unique_corridors = row['Corridor']

    print(f"Vehicle No.: {vehicle_no}")
    print(f"Total OPTD_ KMS: {total_optd_kms}")
    print(f"Unique SERVICE: {unique_service_numbers}")
    print(f"Unique Corridors: {unique_corridors}")
    print("===")

    # Save the result to an Excel file
aggregated_data.to_excel("Non - Adas aggregated.xlsx", index=False)
# Out:
# Vehicle No.: TS01Z0095
# Total OPTD_ KMS: 780.0
# Unique SERVICE: ['9011']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS03Z0445
# Total OPTD_ KMS: 8682.0
# Unique SERVICE: ['PUNE' '9015']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS03Z0446
# Total OPTD_ KMS: 9099.0
# Unique SERVICE: ['PUNE' 'NDL4' 'PDP1' 'NDL1']
# Unique Corridors: [nan 'Bangalore' 'Vijayawada (140 km)']
# ===
# Vehicle No.: TS05Z0171
# Total OPTD_ KMS: 16361.0
# Unique SERVICE: ['2962' '1632' '2852' '3022' '2942' '2932' '2862' '1832' '2832' '2922'
#  '2972' '3012' '1652']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS05Z0176
# Total OPTD_ KMS: 10620.0
# Unique SERVICE: ['2251' '2261' '2181' '2191' 'RJV9' '1601' 'RJV6' '1511' '2271']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS06Z0207
# Total OPTD_ KMS: 410.0
# Unique SERVICE: ['9011']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS06Z0231
# Total OPTD_ KMS: 15340.0
# Unique SERVICE: ['2082' '2552' '2522' '2022' '2051' '2061' '2072' '1961' '2102' '1992']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4006
# Total OPTD_ KMS: 16420.0
# Unique SERVICE: ['2632' '2702' '2622' '2732' '2642' '2782' '2712' '2792' '2662' '9034'
#  '2612']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4070
# Total OPTD_ KMS: 12270.0
# Unique SERVICE: ['2872' '3032' '2842' '3002' '1622']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4072
# Total OPTD_ KMS: 12296.0
# Unique SERVICE: ['2872' '3032' '1622' '3002' '9055']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4073
# Total OPTD_ KMS: 15070.0
# Unique SERVICE: ['1622' '9052' '3002' '2842' '2872' '2942' '2932' '2972' '3032' '1732']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4074
# Total OPTD_ KMS: 14215.0
# Unique SERVICE: ['2842' '3002' '2872' '3032' '1632' '1622' '1712' '9045' '9052' '2862'
#  '3022']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4075
# Total OPTD_ KMS: 14237.0
# Unique SERVICE: ['ADB7' 'ADB6' 'ADB5' 'ADB4' '9052']
# Unique Corridors: ['Adilabad' nan]
# ===
# Vehicle No.: TS07Z4076
# Total OPTD_ KMS: 3838.0
# Unique SERVICE: ['GV07' 'GV06' '301' 'RJV7' 'GBC2' '9011']
# Unique Corridors: ['Vijayawada' '0' nan]
# ===
# Vehicle No.: TS07Z4083
# Total OPTD_ KMS: 17192.0
# Unique SERVICE: ['ADB6' 'ADB5' 'ADB4' 'ADB7']
# Unique Corridors: ['Adilabad']
# ===
# Vehicle No.: TS07Z4085
# Total OPTD_ KMS: 14918.0
# Unique SERVICE: ['GV02' 'GV03' 'GV04' 'GV07' '2131' 'GV01' 'GBC4' 'RJV3']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4086
# Total OPTD_ KMS: 16598.0
# Unique SERVICE: ['GV03' '301' '323' 'GBC1' 'RJV7' 'GBC5' 'GV04' 'GBC3' 'GBC2']
# Unique Corridors: ['Vijayawada' '0' nan]
# ===
# Vehicle No.: TS07Z4089
# Total OPTD_ KMS: 16856.0
# Unique SERVICE: ['3002' '2842' '2872' '2972' '1622' '3032']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4090
# Total OPTD_ KMS: 260.0
# Unique SERVICE: ['1622']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4111
# Total OPTD_ KMS: 16551.0
# Unique SERVICE: ['ADB4' 'ADB6' 'ADB7' 'BNGC' 'BNGE' 'ADB5']
# Unique Corridors: ['Adilabad' 'Bangalore']
# ===
# Vehicle No.: TS07Z4113
# Total OPTD_ KMS: 11261.5
# Unique SERVICE: ['ADB4' 'ADB5' 'ADB7' '9051' 'BNGC' 'ADB6' 'BNGD']
# Unique Corridors: ['Adilabad' nan 'Bangalore']
# ===
# Vehicle No.: TS07Z6666
# Total OPTD_ KMS: 560.0
# Unique SERVICE: ['ZC']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS08Z0052
# Total OPTD_ KMS: 460.0
# Unique SERVICE: ['9011']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS08Z0059
# Total OPTD_ KMS: 250.0
# Unique SERVICE: ['9011']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS08Z0066
# Total OPTD_ KMS: 4512.0
# Unique SERVICE: ['2171' '9011' '2271' 'GV07' 'GV05' '2251' '2181']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0070
# Total OPTD_ KMS: 16734.0
# Unique SERVICE: ['322' '9025' '323' 'GV02' 'GBC2' 'GV04' 'GBC3' 'RJV3' '1541' 'GBC5']
# Unique Corridors: ['0' nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0071
# Total OPTD_ KMS: 14495.0
# Unique SERVICE: ['324' '325' 'GBC4' 'GBC5' 'GBC3' '9011' 'GV04' '3302']
# Unique Corridors: ['0' nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0114
# Total OPTD_ KMS: 10053.0
# Unique SERVICE: ['224' 'RJV2' 'RJV3' '2171' 'RJV4' '2181' 'RJV6' '2251' '9028' '2191'
#  'GV02' 'RJV5']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0115
# Total OPTD_ KMS: 16660.0
# Unique SERVICE: ['1541' '2161' '321' '211' '212' 'RJV7' '2201' '2191' '2181' '2251' 'GV07'
#  'GV06' 'RJV9' 'RJV6' 'RJV8' '2271']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0122
# Total OPTD_ KMS: 220.0
# Unique SERVICE: ['1622']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0124
# Total OPTD_ KMS: 11912.0
# Unique SERVICE: ['9008' 'RC35' 'RC49' 'RCR7' 'RC18' 'GLB6' 'MTM5' 'MTM4' 'RC15' '9506'
#  'RC51' 'RC53' 'RC20' 'RC26' 'RC01' 'GLB4' 'YGR8']
# Unique Corridors: [nan 'Bangalore' 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0126
# Total OPTD_ KMS: 12729.0
# Unique SERVICE: ['3012' '3022' '2942' '2922' '2852' '1652' '2832' '1832' '1732' '3052'
#  '2882' '9042']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0129
# Total OPTD_ KMS: 11964.0
# Unique SERVICE: ['RC18' 'RC20' 'GLB6' 'GLB1' 'RC26' 'RC51' 'SDM4' 'RC49' '9006' 'YGR8'
#  'RC53' 'RCR7' '9003' '9002' 'MTM1']
# Unique Corridors: ['Bangalore' 'Others' nan 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0130
# Total OPTD_ KMS: 13462.0
# Unique SERVICE: ['9001' 'RC18' '9501' 'RC15' 'GLB5' 'GLB6' 'MTM4' 'RC49' 'YGR8' 'RC51'
#  '9003' '9004' 'RC35' 'YGR7' '9002' 'GLB4' 'GLB1']
# Unique Corridors: [nan 'Bangalore' 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0133
# Total OPTD_ KMS: 13846.0
# Unique SERVICE: ['2622' '2632' '2612' '1732' '2702' '2852' '3042']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0138
# Total OPTD_ KMS: 10836.0
# Unique SERVICE: ['2972' '2652' '2782' '2792' '2632' '2622' '2702' '1642' '2612' '2982'
#  '1732']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0143
# Total OPTD_ KMS: 710.0
# Unique SERVICE: ['9051' '9005']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS08Z0144
# Total OPTD_ KMS: 9265.0
# Unique SERVICE: ['SHRD' '9053']
# Unique Corridors: ['0' nan]
# ===
# Vehicle No.: TS08Z0149
# Total OPTD_ KMS: 3048.0
# Unique SERVICE: ['2171' '1541' '317' '2251' 'GV07' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0150
# Total OPTD_ KMS: 9598.0
# Unique SERVICE: ['2171' 'RJV5' '2191' '2271' 'GV05' 'GV06' '2251' '9011' 'RJV1' 'RJV2'
#  '1601' '2161']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0153
# Total OPTD_ KMS: 9440.0
# Unique SERVICE: ['2552' '2522' '2092' '2022' '2041' '6661' '2532' '2002' '1992']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0154
# Total OPTD_ KMS: 12502.0
# Unique SERVICE: ['2131' '2171' '304' '9011' '2181' '1551' '2261' '1511' 'GV05' 'RJV5'
#  '2191' 'GV02' 'GV06']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0155
# Total OPTD_ KMS: 10742.0
# Unique SERVICE: ['224' '9011' 'RJV1' '2261' '1551' '2201' '2161' 'RJV5' 'GV02' 'GV06'
#  'GV07' '2171']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0159
# Total OPTD_ KMS: 15382.0
# Unique SERVICE: ['2161' '2191' '321' '304' '1511' '1601' '2271' 'RJV6' '2201' 'RJV8'
#  '2181' 'GV06' 'GV02' '2261' 'RJV2']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0160
# Total OPTD_ KMS: 5830.0
# Unique SERVICE: ['2191' '2271' '9011' 'RJV9' '2201' 'RJV1' '1511' 'RJV2']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0168
# Total OPTD_ KMS: 11413.0
# Unique SERVICE: ['2662' '2612' '2622' '2632' '2912' '2652' '2962' '2922' '2982' '3102'
#  '2732' '2792' '2642' '1622']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0170
# Total OPTD_ KMS: 15688.0
# Unique SERVICE: ['3052' '2612' '2952' '2652' '2642' '2782' '2632' '2622' '9031' '1752'
#  '2662' '9036' '2962' '2702' '2722']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0176
# Total OPTD_ KMS: 11332.0
# Unique SERVICE: ['RC01' 'GLB6' 'GLB5' 'RC35' 'RC46' 'RC18' 'BCK3' 'RC02' 'YGR2' 'RC15'
#  'SDM2' 'GLB4' 'GLB3' 'BCK4' 'GLB1' 'RC26']
# Unique Corridors: ['Bangalore' 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0177
# Total OPTD_ KMS: 8554.0
# Unique SERVICE: ['SDM3' 'RC46' '9002' 'YGR1' 'BCK3' 'RCR7' 'RC01' 'SDM2' 'SDM1' 'YGR8'
#  'MTM5' 'SDM4' 'RC35']
# Unique Corridors: ['Others' 'Bangalore' nan 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0178
# Total OPTD_ KMS: 12072.0
# Unique SERVICE: ['RC51' 'GLB4' 'GLB1' 'YGR8' 'GLB3' 'GLB5' 'RC35' 'SDM2' 'YGR2' 'SDM1'
#  'BCK3' 'YGR5' 'RC37']
# Unique Corridors: ['Bangalore' 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0179
# Total OPTD_ KMS: 11760.0
# Unique SERVICE: ['RC35' 'SDM2' 'GLB3' 'GLB1' 'YGR8' 'RC46' 'SDM1' 'RC20' 'SEDM' 'YGR2'
#  'GLB5' 'GLB6' 'YGR1' 'SDM4' 'BCK3' 'YGR5']
# Unique Corridors: ['Bangalore' 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0181
# Total OPTD_ KMS: 16272.0
# Unique SERVICE: ['2782' '2942' '2612' '2632' '2702' '1642' '9031' '2972' '2652' '2642'
#  '9042' '3052' '2622' '1752' '2792' '2722' '2952' '1732']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0182
# Total OPTD_ KMS: 15253.0
# Unique SERVICE: ['2702' '2912' '2622' '2632' '2972' '2922' '9038' '2732' '2942' '2952'
#  '3042' '9032' '3112' '2612' '2722' '9033' '2642']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0183
# Total OPTD_ KMS: 16190.0
# Unique SERVICE: ['2622' '3042' '2652' '2782' '2792' '3052' '2972' '3122' '3012' '2632'
#  '9031' '3102' '9038' '9036' '1832' '2732']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0192
# Total OPTD_ KMS: 13442.0
# Unique SERVICE: ['GLB5' 'RC46' '9005' 'YGR5' '9004' 'GLB4' 'BCK4' 'RC18' 'MTM4' 'YGR2'
#  'RCR7' 'SDM1' 'RC01' 'RC51' 'GLB6']
# Unique Corridors: ['Others' 'Bangalore' nan 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0194
# Total OPTD_ KMS: 11906.0
# Unique SERVICE: ['YGR1' 'RC01' 'RC37']
# Unique Corridors: ['Bangalore (200 km)' 'Bangalore']
# ===
# Vehicle No.: TS08Z0202
# Total OPTD_ KMS: 10800.0
# Unique SERVICE: ['GV04' 'GV05' 'GV02' 'GV01' 'GV03' 'RJV3' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0203
# Total OPTD_ KMS: 3980.0
# Unique SERVICE: ['9011' 'GV03' 'RJV3' 'RJV7' '9005']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0204
# Total OPTD_ KMS: 12762.0
# Unique SERVICE: ['GV01' 'GV02' 'GV07' '1541' 'GV03' 'RJV3' 'GBC4' 'GBC5' 'RJV7']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0205
# Total OPTD_ KMS: 9742.0
# Unique SERVICE: ['301' '212' 'GV07' 'GV03' '9011' 'GBC1' '1541' 'GV04' '2131']
# Unique Corridors: ['0' 'Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0206
# Total OPTD_ KMS: 14428.0
# Unique SERVICE: ['GV05' 'GV04' 'GV01' 'GV06' 'RJV3' '9011' '1541' 'GBC4' 'GBC5']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0207
# Total OPTD_ KMS: 10690.0
# Unique SERVICE: ['324' '9011' 'GV03' 'GV04' 'GV02' 'GBC5' 'GV01' 'GBC1' '9020' 'RJV7'
#  'GBC2' '9027']
# Unique Corridors: ['0' nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0209
# Total OPTD_ KMS: 9053.0
# Unique SERVICE: ['3302' '315' 'GB08' 'RJV7']
# Unique Corridors: ['Vijayawada' 'Bangalore' nan]
# ===
# Vehicle No.: TS08Z0210
# Total OPTD_ KMS: 12360.0
# Unique SERVICE: ['1622' '1652' '1632' '2842' '3002' '3102' '3032']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0211
# Total OPTD_ KMS: 15321.0
# Unique SERVICE: ['GV03' 'GV06' 'GV07' 'GV04' 'GV02' 'GV05' 'RJV3' 'GBC5' '9026' 'GBC3'
#  '9030' '1541' 'GBC1']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0212
# Total OPTD_ KMS: 12572.0
# Unique SERVICE: ['315' 'GB08' 'RJV7' 'GBC5' '9001' 'GBC1' 'GBC3']
# Unique Corridors: ['Bangalore' nan]
# ===
# Vehicle No.: TS08Z0213
# Total OPTD_ KMS: 17592.0
# Unique SERVICE: ['9501' '323' '9028' 'GV07' '2161' 'GBC3' 'GBC5' 'GBC4' 'GV04' '9023'
#  'GBC2' '9027' '2131']
# Unique Corridors: [nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS08Z0214
# Total OPTD_ KMS: 440.0
# Unique SERVICE: ['1652' '1622']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0215
# Total OPTD_ KMS: 11528.0
# Unique SERVICE: ['GBC2' 'GBC1' 'GM09']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS08Z0216
# Total OPTD_ KMS: 10556.0
# Unique SERVICE: ['323' '3302' 'GB08']
# Unique Corridors: ['0' 'Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0217
# Total OPTD_ KMS: 13608.0
# Unique SERVICE: ['325' '315' '324' 'GBC5' 'GBC4' 'GM09' 'GB08' 'RJV3' 'GV01' 'GBC1']
# Unique Corridors: ['0' 'Bangalore' nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0218
# Total OPTD_ KMS: 17766.0
# Unique SERVICE: ['316' 'GV07' '322' '324' 'GBC2' 'GV01' '2131' 'RJV7' '1541' 'GV03' 'GBC5'
#  'GBC4']
# Unique Corridors: ['Bangalore' 'Vijayawada' '0' nan]
# ===
# Vehicle No.: TS08Z0220
# Total OPTD_ KMS: 13256.0
# Unique SERVICE: ['YGR2' 'GLB6' 'MTM4' 'GLB1' 'RC51' '9002' 'YGR7' 'MTM5' 'RC46' 'BCK3'
#  'RC01' 'GLB3']
# Unique Corridors: ['Bangalore (200 km)' 'Others' 'Bangalore' nan]
# ===
# Vehicle No.: TS08Z0221
# Total OPTD_ KMS: 0.0
# Unique SERVICE: ['9507']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS08Z0242
# Total OPTD_ KMS: 16520.0
# Unique SERVICE: ['2072' '2532' '2102' '2542' '2552' '1992' '2522' '2082' '2051']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0243
# Total OPTD_ KMS: 15670.0
# Unique SERVICE: ['1712' '2832' '2922' '1832' '3022' '2932' '3012' '1732' '3042' '1642'
#  '2992' '2962' '2982' '2912' '2862']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0244
# Total OPTD_ KMS: 11870.0
# Unique SERVICE: ['271' '2191' '2201' '9011' 'RJV4' '2131' 'RJV2' '2261' '1511' 'GV05'
#  '2271' 'GV02' '1551' 'RJV5' '2181' 'RJV8']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0245
# Total OPTD_ KMS: 11657.0
# Unique SERVICE: ['321' '9011' 'RJV1' '1601' '1551' '1511' '2171' 'RJV2' '2161' '2201'
#  '2191' '9030' 'RJV4' 'GV06' '9025' 'RJV5' 'RJV6' 'RJV8']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0246
# Total OPTD_ KMS: 15396.0
# Unique SERVICE: ['304' '2201' '2251' '2191' '271' '1541' '2171' 'RJV8' '2161' 'RJV9'
#  '2271' '2261' 'GV02' 'GV06' 'RJV4' '2181' '1551' 'GV07']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0248
# Total OPTD_ KMS: 13926.0
# Unique SERVICE: ['2922' '1712' '3022' '1652' '3012' '1632' '3042' '2942' '2962' '1642'
#  '2932']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0249
# Total OPTD_ KMS: 8604.0
# Unique SERVICE: ['SHRD']
# Unique Corridors: ['0']
# ===
# Vehicle No.: TS08Z0250
# Total OPTD_ KMS: 9702.0
# Unique SERVICE: ['2992' '3022' '1652' '2932' '2942' '2922' '1622' '1642' '1632' '3012']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0251
# Total OPTD_ KMS: 13344.0
# Unique SERVICE: ['1632' '2852' '1832' '2932' '2942' '1642' '2962' '2952' '1622' '2912'
#  '2922' '2732' '3012' '1652' '1712']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0252
# Total OPTD_ KMS: 16916.0
# Unique SERVICE: ['3022' '2942' '1622' '1642' '2932' '1712' '1632' '2872' '1652' '2832'
#  '2912' '2922']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0253
# Total OPTD_ KMS: 13864.0
# Unique SERVICE: ['1832' '1732' '3012' '1712' '1632' '1642' '1622' '2862' '2852' '2982'
#  '2972' '3022']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0254
# Total OPTD_ KMS: 10273.0
# Unique SERVICE: ['2171' '2201' '317' '321' '2251' '2181' '1601' 'RJV1' 'GV02' '1511'
#  'GV05' '9011' '9002']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0255
# Total OPTD_ KMS: 15058.0
# Unique SERVICE: ['2932' '1642' '2922' '2942' '2962' '1712' '1832' '3052' '9046' '1632'
#  '2972' '1732' '3012' '2612']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0261
# Total OPTD_ KMS: 10324.0
# Unique SERVICE: ['2181' '9011' '271' '270' 'RJV6' '2271' 'RJV7' 'RJV4' '2251' '2161'
#  'RJV8' 'RJV9']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0264
# Total OPTD_ KMS: 12276.0
# Unique SERVICE: ['1732' '3012' '2972' '2882' '1632' '2962' '2932' '3042' '2942' '3052']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0265
# Total OPTD_ KMS: 11806.0
# Unique SERVICE: ['9502' '316' '9011' 'GM09' '1541']
# Unique Corridors: [nan 'Bangalore' 'Vijayawada']
# ===
# Vehicle No.: TS08Z0266
# Total OPTD_ KMS: 9708.0
# Unique SERVICE: ['316' 'GM09' '9011' 'RJV7']
# Unique Corridors: ['Bangalore' nan]
# ===
# Vehicle No.: TS08Z0267
# Total OPTD_ KMS: 5741.0
# Unique SERVICE: ['9011' 'GV06' 'GM09' '323' 'RJV7' 'GV04' '1541' '2131' '3302']
# Unique Corridors: [nan 'Vijayawada' '0']
# ===
# Vehicle No.: TS08Z0268
# Total OPTD_ KMS: 9282.0
# Unique SERVICE: ['3302']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0269
# Total OPTD_ KMS: 11897.0
# Unique SERVICE: ['BNGD' 'BNGE' 'BNGC' 'ADB5' '9052' '9051' 'ADB4']
# Unique Corridors: ['Bangalore' 'Adilabad' nan]
# ===
# Vehicle No.: TS08Z0270
# Total OPTD_ KMS: 9010.5
# Unique SERVICE: ['9006' 'BNGD' 'BNGE' 'BNGC' 'ADB5' '9051' '9005']
# Unique Corridors: [nan 'Bangalore' 'Adilabad']
# ===
# Vehicle No.: TS08Z0271
# Total OPTD_ KMS: 13157.5
# Unique SERVICE: ['ADB5' 'BNGC' 'BNGD' 'BNGE' 'ADB6']
# Unique Corridors: ['Adilabad' 'Bangalore']
# ===
# Vehicle No.: TS08Z0272
# Total OPTD_ KMS: 7449.0
# Unique SERVICE: ['BNGC' 'BNGE' 'BNGD' 'ADB5' '9051']
# Unique Corridors: ['Bangalore' 'Adilabad' nan]
# ===
# Vehicle No.: TS08Z0273
# Total OPTD_ KMS: 13774.0
# Unique SERVICE: ['1601' '223' 'RJV6' '2171' 'RJV5' '9011' '2251' '2161' '1511' 'RJV2'
#  '2261' 'RJV9' '2191' 'GV06' 'RJV8']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0274
# Total OPTD_ KMS: 16752.0
# Unique SERVICE: ['2261' '1551' '270' '2131' '2271' '1511' '9011' '1541' 'RJV7' 'RJV6'
#  'RJV2' 'GV02' '1601' 'RJV1' 'RJV4' '9002']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0275
# Total OPTD_ KMS: 14120.0
# Unique SERVICE: ['271' '317' '212' '2161' '1541' '1551' 'RJV5' 'RJV9' 'RJV1' 'GV07' '2271'
#  '2261' '2201' '2251' '9003' 'RJV6' 'GV06' 'RJV4' 'GV05']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0276
# Total OPTD_ KMS: 16826.0
# Unique SERVICE: ['1511' '2131' '2261' '1551' '223' '211' '2181' 'RJV4' '1541' 'GV05'
#  '2271' 'GV02' '2302' 'GV07' 'GV06' '9071' 'RJV6' 'RJV2' '1601' 'RJV1']
# Unique Corridors: ['Vijayawada' nan 'Bangalore']
# ===
# Vehicle No.: TS08Z0277
# Total OPTD_ KMS: 12042.0
# Unique SERVICE: ['YGR7' 'RC51' 'RC49' '9003' 'RCR7' 'GLB5' 'SDM1' 'RC46' '9004' '9001']
# Unique Corridors: ['Bangalore (200 km)' 'Bangalore' nan 'Others']
# ===
# Vehicle No.: TS08Z0278
# Total OPTD_ KMS: 12336.0
# Unique SERVICE: ['GLB1' '9002' 'RC26' 'SDM1' 'RC01' 'MTM5' 'RC46' 'BCK4' 'RCR7' 'RC18'
#  'RC35' 'RC49' 'RC15' 'GLB5' 'GLB4']
# Unique Corridors: ['Others' nan 'Bangalore']
# ===
# Vehicle No.: TS08Z0279
# Total OPTD_ KMS: 13650.5
# Unique SERVICE: ['BNGC' 'ADB7' 'BNGD' 'BNGE' 'ADB6']
# Unique Corridors: ['Bangalore' 'Adilabad']
# ===
# Vehicle No.: TS08Z0280
# Total OPTD_ KMS: 14470.0
# Unique SERVICE: ['BNGE' 'ADB4' 'ADB6' 'ADB5' 'BNGD' 'ADB7' 'BNGC']
# Unique Corridors: ['Bangalore' 'Adilabad']
# ===
# Vehicle No.: TS08Z0283
# Total OPTD_ KMS: 10648.0
# Unique SERVICE: ['MTM5' 'RC26' 'RC53' 'RC46' 'SDM1' 'YGR8' 'RC01' 'RC18' 'MTM4' 'RC15'
#  'GLB3' 'SDM3' 'RC37' 'RCR7']
# Unique Corridors: ['Bangalore' 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0284
# Total OPTD_ KMS: 5987.0
# Unique SERVICE: ['2642' '2612' '2632' '3012' '2702' '1712' '9031' '2732' '2622' '2972']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0285
# Total OPTD_ KMS: 4720.0
# Unique SERVICE: ['1961' '2542' '2051' '2522' '2002' '2222']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0286
# Total OPTD_ KMS: 12030.0
# Unique SERVICE: ['GLB6' 'RC15' 'MTM5' 'RC26' 'RC20' 'YGR2' 'BCK3' 'GLB3' 'GLB1' 'RC51'
#  'RC35' 'RC37' 'YGR7' 'RCR7' 'GLB5' 'MTM4' 'RC46' 'GLB4']
# Unique Corridors: ['Others' 'Bangalore' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0287
# Total OPTD_ KMS: 8556.0
# Unique SERVICE: ['MTM4' 'RC01' 'BCK3' 'SDM4' 'RC18' 'RC15' '9006' 'YGR7' 'RC35' 'RC46'
#  'RC40' 'MTM5' 'RC37' 'MTY2']
# Unique Corridors: ['Bangalore' 'Others' nan 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0288
# Total OPTD_ KMS: 11365.0
# Unique SERVICE: ['2792' '2652' '2612' '9031' '2632' '2642' '2722' '9033' '2622' '1732'
#  '2702' '2852']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0289
# Total OPTD_ KMS: 3426.0
# Unique SERVICE: ['RC46' 'YGR8' 'YGR7' 'RC01' '9003' 'YGR5' 'GLB1']
# Unique Corridors: ['Bangalore' 'Bangalore (200 km)' nan 'Others']
# ===
# Vehicle No.: TS08Z0290
# Total OPTD_ KMS: 8310.0
# Unique SERVICE: ['2532' '2092' '9011' '2102' '1961' '2222' '7771' '2051' '2202' '1992'
#  '2522' '2041']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0291
# Total OPTD_ KMS: 5900.0
# Unique SERVICE: ['2051' '2552' '2002' '2222' '2522' '2512' '2082']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0292
# Total OPTD_ KMS: 7968.0
# Unique SERVICE: ['SLP2' 'KRN1' 'NDL5' '9009' 'NDL2' '9010' '9005']
# Unique Corridors: ['Others' 'Bangalore' nan]
# ===
# Vehicle No.: TS09Z7609
# Total OPTD_ KMS: 2016.0
# Unique SERVICE: ['1732' '2942' '2952' '1712']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7618
# Total OPTD_ KMS: 9790.0
# Unique SERVICE: ['1652' '1622' '2852' '2992' '1642' '2962' '1832' '2932']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7621
# Total OPTD_ KMS: 14806.0
# Unique SERVICE: ['1601' '211' '2261' '1511' '1551' '9011' 'RJV3' '2131' 'GV02' 'RJV2'
#  'RJV1' '2181' '2191' 'RJV8' 'GV07' 'RJV6' '2201']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7622
# Total OPTD_ KMS: 4340.0
# Unique SERVICE: ['2191' '1601' '2271' 'RJV5' 'RJV9' '9023' '2161' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7627
# Total OPTD_ KMS: 17478.0
# Unique SERVICE: ['2982' '1732' '1632' '2852' '1652' '3012' '2992' '2832' '2952' '3052'
#  '2922' '2912' '2972' '1642' '1622']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7629
# Total OPTD_ KMS: 15652.0
# Unique SERVICE: ['2852' '1652' '2992' '3022' '2832' '3052' '2932' '2982' '2972' '2912'
#  '1642']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7638
# Total OPTD_ KMS: 13864.0
# Unique SERVICE: ['2942' '2852' '2932' '1622' '2962' '1732' '2922' '2912' '2972' '2652'
#  '2882' '1712' '1652' '2992']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7642
# Total OPTD_ KMS: 12351.0
# Unique SERVICE: ['1551' '270' '271' '2251' '2171' 'RJV3' 'RJV4' '2161' 'GV05' 'RJV6'
#  '2271' '1511' '9501' 'RJV5']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7655
# Total OPTD_ KMS: 11578.0
# Unique SERVICE: ['1642' '9041' '1632' '2852' '1652' '1622' '2982' '2832' '2952' '2992'
#  '1832' '3052']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7659
# Total OPTD_ KMS: 6080.0
# Unique SERVICE: ['1622' '9041' '3042' '2982' '3052' '2912' '1642']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7668
# Total OPTD_ KMS: 13603.0
# Unique SERVICE: ['2251' '212' '2271' '270' '1551' '317' '2161' 'RJV1' '2201' '9011' 'RJV8'
#  '2181' '1511' '9502' '2191']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7674
# Total OPTD_ KMS: 7670.0
# Unique SERVICE: ['2191' '304' 'RJV8' 'RJV1' 'RJV6' '1511' '2271' '2251' '1551' '9011'
#  '2161']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7677
# Total OPTD_ KMS: 16664.0
# Unique SERVICE: ['2832' '2992' '2942' '2952' '2932' '1642' '2962' '2982' '2912' '1632'
#  '1652' '2922' '3052' '2852' '1832']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7680
# Total OPTD_ KMS: 17458.0
# Unique SERVICE: ['2912' '2972' '1622' '2962' '2842' '2852' '9041' '1642' '2942' '2982'
#  '1732' '1712' '2992' '1832' '3052' '2922' '2932']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7682
# Total OPTD_ KMS: 16856.0
# Unique SERVICE: ['1622' '2962' '2912' '2842' '3052' '1642' '2922' '2952' '1632' '2832'
#  '2992' '3012' '1732' '2852']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7791
# Total OPTD_ KMS: 1140.0
# Unique SERVICE: ['9011']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS09Z7809
# Total OPTD_ KMS: 1010.0
# Unique SERVICE: ['CH']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS09Z7818
# Total OPTD_ KMS: 14245.0
# Unique SERVICE: ['2722' '2792' '1752' '9032' '3102' '3122' '2852' '2662']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7821
# Total OPTD_ KMS: 590.0
# Unique SERVICE: ['2542']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7825
# Total OPTD_ KMS: 12203.0
# Unique SERVICE: ['2712' '9032' '3052' '2662' '2782' '2792' '2732' '9031' '1642' '2952'
#  '2592' '2722']
# Unique Corridors: ['Vijayawada' nan 'Others']
# ===
# Vehicle No.: TS09Z7826
# Total OPTD_ KMS: 14750.0
# Unique SERVICE: ['2202' '2542' '2532' '2102' '2222' '7771' '2512' '2051' '2041' '2072'
#  '1961' '2002' '2061']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7827
# Total OPTD_ KMS: 16263.0
# Unique SERVICE: ['2512' '2051' '2041' '2022' '2222' '7771' '2002' '2102' '2542' '2072'
#  '2522' '9026' '2092' '9020' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7828
# Total OPTD_ KMS: 14760.0
# Unique SERVICE: ['2522' '7771' '9030' '4441' '2092' '1992' '2102' '2002' '2542' '2202'
#  '3331' '6661']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7829
# Total OPTD_ KMS: 15376.0
# Unique SERVICE: ['6661' '2051' '9011' '2082' '4441' '2102' '2092' '2532' '3331' '2072'
#  '2061' '1931' '2512' '2022']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7830
# Total OPTD_ KMS: 11529.0
# Unique SERVICE: ['2732' '9032' '2792' '2642' '3122' '9038' '9036' '3102' '9031' '2702'
#  '2662']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7848
# Total OPTD_ KMS: 620.0
# Unique SERVICE: ['JP']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS09Z7852
# Total OPTD_ KMS: 15431.0
# Unique SERVICE: ['2092' '2552' '2102' '1931' '2022' '2072' '2061' '2202' '2082' '4441'
#  '9022' '1961' '2512' '2522' '2002' '2251' '1992' '2542']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7857
# Total OPTD_ KMS: 16021.0
# Unique SERVICE: ['2051' '3331' '1992' '6661' '7771' '1931' '2072' '4441' '2542' '2552'
#  '1961' '2102' '2092' '2532' '9027' '2022' '2512']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7859
# Total OPTD_ KMS: 16808.0
# Unique SERVICE: ['2201' '6661' '2002' '1931' '2041' '2102' '2542' '2552' '2202' '2512'
#  '2072']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7860
# Total OPTD_ KMS: 14170.0
# Unique SERVICE: ['1992' '9029' '2082' '3331' '2202' '2022' '2051' '2552' '2061' '2512'
#  '2222' '2092' '1961' '2002' '6661' '7771']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7870
# Total OPTD_ KMS: 8790.0
# Unique SERVICE: ['2292' '314' 'ASB1' '2322' '2302' '9011' '9028']
# Unique Corridors: ['Bangalore' nan 'Vijayawada']
# ===
# Vehicle No.: TS09Z7871
# Total OPTD_ KMS: 15122.0
# Unique SERVICE: ['9008' 'ADN2' '9009' 'NDL1' 'NDL2' 'KRNL' '9050' 'NDL5' '9010' 'ADN1']
# Unique Corridors: [nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7872
# Total OPTD_ KMS: 16088.0
# Unique SERVICE: ['2002' '2041' '1961' '2072' '2061' '2202' '9020' '2051' '9030' '2092'
#  '2522' '1992' '2222']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7874
# Total OPTD_ KMS: 9717.0
# Unique SERVICE: ['2302' 'ASB1']
# Unique Corridors: ['Bangalore' nan]
# ===
# Vehicle No.: TS09Z7875
# Total OPTD_ KMS: 5350.5
# Unique SERVICE: ['2312' '2302' 'ASB1' '9011']
# Unique Corridors: ['Bangalore' nan]
# ===
# Vehicle No.: TS09Z7876
# Total OPTD_ KMS: 10489.0
# Unique SERVICE: ['2292' 'ASB1']
# Unique Corridors: ['Bangalore' nan]
# ===
# Vehicle No.: TS09Z7877
# Total OPTD_ KMS: 9267.0
# Unique SERVICE: ['2312' '2292' 'ASB1']
# Unique Corridors: ['Bangalore' nan]
# ===
# Vehicle No.: TS09Z7880
# Total OPTD_ KMS: 9335.0
# Unique SERVICE: ['2682' '2672']
# Unique Corridors: ['Vijayawada' 'Bangalore']
# ===
# Vehicle No.: TS09Z7881
# Total OPTD_ KMS: 13665.0
# Unique SERVICE: ['AMVY' 'MKP2' '9004' 'ADN2' 'NGPM' 'ADN1' 'NDL5' 'NDL1' '9022' 'KRNL'
#  '9011' '9005' '9023' 'KRN1' 'NDL3']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7882
# Total OPTD_ KMS: 17553.5
# Unique SERVICE: ['ADN1' 'AMVY' 'ADN2' '9004' 'NGP2' '9502' 'SLP2']
# Unique Corridors: ['Bangalore' '0' nan 'Others']
# ===
# Vehicle No.: TS09Z7884
# Total OPTD_ KMS: 9904.0
# Unique SERVICE: ['2672']
# Unique Corridors: ['Bangalore']
# ===
# Vehicle No.: TS09Z7885
# Total OPTD_ KMS: 10704.0
# Unique SERVICE: ['2682']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7886
# Total OPTD_ KMS: 9985.0
# Unique SERVICE: ['2672' '2682' '2692']
# Unique Corridors: ['Bangalore' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7888
# Total OPTD_ KMS: 10065.0
# Unique SERVICE: ['2692' '2672']
# Unique Corridors: ['Vijayawada' 'Bangalore']
# ===
# Vehicle No.: TS09Z7889
# Total OPTD_ KMS: 9394.0
# Unique SERVICE: ['2692']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7890
# Total OPTD_ KMS: 15100.0
# Unique SERVICE: ['2041' '2051' '2022' '2512' '2542' '4441' '2082' '1961' '2072' '2092'
#  '2532' '3331' '9502' '2222']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7891
# Total OPTD_ KMS: 14456.0
# Unique SERVICE: ['4441' '2542' '2202' '3331' '2082' '1961' '2072' '6661' '2522' '2092'
#  '9022' '2022' '2051' '2102' 'RJV6']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7892
# Total OPTD_ KMS: 4720.0
# Unique SERVICE: ['2041' '3331' '2082' '2102' '2092' '2532']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7897
# Total OPTD_ KMS: 15168.0
# Unique SERVICE: ['NDL1' 'PDP1' 'NDL4' '9022' 'RPR1' 'VJA2' 'NDL2' '9015' 'NDL5' 'NDL3'
#  'KRNL' 'MKP2' '9001' 'ADN1' 'ADN2']
# Unique Corridors: ['Bangalore' 'Vijayawada (140 km)' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7898
# Total OPTD_ KMS: 17324.0
# Unique SERVICE: ['1931' '7771' '2522' '2002' '2222' '2041' '6661' '2102' '1992' '9030'
#  '2552' '1961' '3331']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7902
# Total OPTD_ KMS: 13794.0
# Unique SERVICE: ['NDL2' 'KRN1' 'KRNL' 'NDL4' 'SLP2' 'NDL5' 'NDL1' '9006' '9021']
# Unique Corridors: ['Bangalore' 'Others' nan]
# ===
# Vehicle No.: TS09Z7909
# Total OPTD_ KMS: 9867.0
# Unique SERVICE: ['2322' '2302']
# Unique Corridors: ['Vijayawada' 'Bangalore']
# ===
# Vehicle No.: TS09Z7910
# Total OPTD_ KMS: 9423.0
# Unique SERVICE: ['314' '2312']
# Unique Corridors: ['Bangalore']
# ===
# Vehicle No.: TS09Z7912
# Total OPTD_ KMS: 13616.0
# Unique SERVICE: ['2542' '2092' '2041' '2222' '2022' '6661' '2202' '2512' '2082' '3331'
#  '2072' 'SB01' '1931' '1961' '2061']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7913
# Total OPTD_ KMS: 15934.0
# Unique SERVICE: ['7771' '2222' '1931' '2041' '2202' '2512' '2061' '2532' '2002' '4441'
#  '1992' '9022' '1961' 'SB01' '9027' '9511' '2092' '9026' '2552' '3331'
#  '2082']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7915
# Total OPTD_ KMS: 15433.0
# Unique SERVICE: ['3331' '2082' '1961' '2061' '4441' '2522' '9023' '6661' '2002' '2102'
#  '2542' '9025' '9020' '2532' '2072']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7916
# Total OPTD_ KMS: 14554.0
# Unique SERVICE: ['2222' '1961' '2552' '4441' '2522' '2002' '6661' '2041' '1931' '7771'
#  '9501' '2022' '9004' '2072' '2202' '2512' '2051']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7917
# Total OPTD_ KMS: 15940.0
# Unique SERVICE: ['SB01' '2072' '2061' '2512' '2002' '2522' '2092' '2532' '3331' 'RJV5'
#  '1992' '9022' '9501' '7771' '6661' '2041' '9026' '2022']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS09Z7918
# Total OPTD_ KMS: 17262.0
# Unique SERVICE: ['9022' 'MKP1' 'MKP2']
# Unique Corridors: [nan '0']
# ===
# Vehicle No.: TS09Z7919
# Total OPTD_ KMS: 17034.0
# Unique SERVICE: ['MKP1' 'MKP2' '9022' '9002' 'NDL5' 'KRNL']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7920
# Total OPTD_ KMS: 10258.0
# Unique SERVICE: ['2322' '2312' '2302']
# Unique Corridors: ['Vijayawada' 'Bangalore']
# ===
# Vehicle No.: TS09Z7921
# Total OPTD_ KMS: 10414.0
# Unique SERVICE: ['314' '2322' '2312' '2292']
# Unique Corridors: ['Bangalore' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7922
# Total OPTD_ KMS: 9020.0
# Unique SERVICE: ['2302' '314' 'ASB1' '9011' '2292' '2322']
# Unique Corridors: ['Bangalore' nan 'Vijayawada']
# ===
# Vehicle No.: TS09Z7925
# Total OPTD_ KMS: 15901.0
# Unique SERVICE: ['2102' '2002' '2092' '2542' '1992' '1931' '3331' '2061' '2202' '2051'
#  '2022' '7771' '6661' '9023' '2512' '2532' '1961' '2072']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7935
# Total OPTD_ KMS: 14619.0
# Unique SERVICE: ['2022' '2061' '2072' '2202' '3331' '2102' '1992' '2002' '2512' '2082'
#  'SB01' '9029' '9023' '2532' '6661']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7938
# Total OPTD_ KMS: 8453.0
# Unique SERVICE: ['SB01' '9020' '2532']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS09Z7941
# Total OPTD_ KMS: 10454.0
# Unique SERVICE: ['PDP1' '9005' '9011' 'NGP2' 'SLP2']
# Unique Corridors: ['Vijayawada (140 km)' nan '0' 'Others']
# ===
# Vehicle No.: TS09Z7945
# Total OPTD_ KMS: 11602.5
# Unique SERVICE: ['NGP2' 'PDP1' 'NGPM' 'AMVY' '9023' '9008' '9014' 'KRNL' '9009' 'RPR1']
# Unique Corridors: ['0' 'Vijayawada (140 km)' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7946
# Total OPTD_ KMS: 10998.5
# Unique SERVICE: ['RPR1' 'AMVY' 'NGP2' 'ADN1' 'NGPM' 'KRNL' '9024']
# Unique Corridors: ['0' 'Bangalore' nan]
# ===
# Vehicle No.: TS09Z7947
# Total OPTD_ KMS: 15122.0
# Unique SERVICE: ['MKP2' 'PDP1' 'SLP2' '9006' 'RPR1' '9010' '9021' '9008' '9001' 'NDL1'
#  '9022' 'NDL3' 'KRN1']
# Unique Corridors: ['0' 'Vijayawada (140 km)' 'Others' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7956
# Total OPTD_ KMS: 9590.0
# Unique SERVICE: ['1961' 'SB01' '9023']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7957
# Total OPTD_ KMS: 10526.0
# Unique SERVICE: ['AMVY' 'NDL3' 'NDL5' 'NDL4' 'PDP1' '9009' '9015' '9006' 'NGPM' 'ADN2'
#  '9021' '9005' '9011']
# Unique Corridors: ['0' 'Bangalore' 'Vijayawada (140 km)' nan]
# ===
# Vehicle No.: TS09Z7958
# Total OPTD_ KMS: 12926.0
# Unique SERVICE: ['NDL5' 'NDL4' 'NDL1' 'KRN1' '9009' '9012' 'NDL2' '9010' 'NDL3' 'KRNL'
#  'RPR1' 'MKP2' 'VJA2' 'AMVY' '9011' '9002']
# Unique Corridors: ['Bangalore' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7960
# Total OPTD_ KMS: 12371.5
# Unique SERVICE: ['NGPM' 'RPR1' '9003' 'ADN1' '9009' 'NGP2' 'NDL5' 'NDL1' '9012' '9021'
#  '9023']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7961
# Total OPTD_ KMS: 10830.5
# Unique SERVICE: ['NGPM' 'RPR1' 'AMVY' 'NGP2' '9010' 'MKP2' 'PDP1']
# Unique Corridors: ['0' nan 'Vijayawada (140 km)']
# ===
# Vehicle No.: TS09Z7962
# Total OPTD_ KMS: 10844.0
# Unique SERVICE: ['NGP2' 'NGPM' 'RPR1' '9015' 'NDL4' '9051' '9054']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7963
# Total OPTD_ KMS: 9775.5
# Unique SERVICE: ['RPR1' '9010' 'NDL4' '9006' 'NGP2' '9021' 'NGPM']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7964
# Total OPTD_ KMS: 15913.0
# Unique SERVICE: ['2072' '2202' '6661' '7771' '2051' '2512' '2022' '2222' '2041' '9026'
#  '2061' '3331' 'SB01']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7972
# Total OPTD_ KMS: 14909.0
# Unique SERVICE: ['VJA2' 'ADN1' 'NDL4' '9005' '9010' 'ADN2' 'NDL2']
# Unique Corridors: ['Vijayawada' 'Bangalore' nan]
# ===
# Vehicle No.: TS09Z7973
# Total OPTD_ KMS: 14226.0
# Unique SERVICE: ['NDL3' '9008' 'NDL2' '9004' '9021' 'AMVY' 'NDL1' '9009' '9051' '9007'
#  'VJA2' '9006' '9010']
# Unique Corridors: ['Bangalore' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7976
# Total OPTD_ KMS: 11952.0
# Unique SERVICE: ['ADN2' '9006' '9004' 'ADN1' 'NDL3' 'NDL2' 'NDL4' '9009' 'NGPM' 'RPR1'
#  'VJA2' 'KRNL']
# Unique Corridors: ['Bangalore' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7977
# Total OPTD_ KMS: 14956.0
# Unique SERVICE: ['NDL4' 'NDL2' 'NDL3' 'KRN1' 'ADN1' 'NGPM' 'RPR1' '9008' '9013' 'NDL1']
# Unique Corridors: ['Bangalore' '0' nan]
# ===
# Vehicle No.: TS09Z7979
# Total OPTD_ KMS: 10280.0
# Unique SERVICE: ['9005' 'KRNL' 'NDL3' 'PDP1' 'KRN1' 'ADN1' '9021' 'NDL4' 'AMVY' 'NGPM'
#  'NDL1']
# Unique Corridors: [nan 'Bangalore' 'Vijayawada (140 km)' '0']
# ===
# Vehicle No.: TS09Z7980
# Total OPTD_ KMS: 14036.0
# Unique SERVICE: ['NDL2' 'NDL1' '9008' '9007' 'NDL4' 'NDL3' 'KRNL' 'SLP2' '9501' '9011'
#  '9024' '9021' 'MKP2' 'MKP1' '9009']
# Unique Corridors: ['Bangalore' nan 'Others' '0']
# ===
# Vehicle No.: TS15Z0171
# Total OPTD_ KMS: 10676.0
# Unique SERVICE: ['270' '2251' '2181' '2191' '2201' '1511' '2261' '2271' 'RJV4' 'GV06'
#  'GV07' 'RJV9' '1551' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0172
# Total OPTD_ KMS: 8554.0
# Unique SERVICE: ['223' '1511' '1601' '2251' 'RJV2' '2181' '2171' '2191' '2161' '9011'
#  'GV02']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0174
# Total OPTD_ KMS: 13846.0
# Unique SERVICE: ['1642' '2852' '1652' '2922' '3042' '2992' '2932' '1732' '3012' '3022'
#  '1712' '1832' '2942' '2912']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS15Z0193
# Total OPTD_ KMS: 13972.0
# Unique SERVICE: ['2642' '2792' '1752' '2732' '2952' '2592' '3122' '3112' '3102' '2702'
#  '2712' '1712' '2852' '2652' '2722']
# Unique Corridors: ['Vijayawada' 'Others' nan]
# ===
# Vehicle No.: TS15Z0200
# Total OPTD_ KMS: 13633.0
# Unique SERVICE: ['3102' '2912' '3112' '2642' '2572' '2712' '2782' '2652']
# Unique Corridors: [nan 'Vijayawada' 'Others']
# ===
# Vehicle No.: TS15Z0201
# Total OPTD_ KMS: 11122.0
# Unique SERVICE: ['2572' '3102' '3122' '9038' '3112']
# Unique Corridors: ['Others' nan]
# ===
# Vehicle No.: TS15Z0202
# Total OPTD_ KMS: 11662.0
# Unique SERVICE: ['9507' '3122' '2582' '3112' '2712' '2572']
# Unique Corridors: [nan 'Others' 'Vijayawada']
# ===
# Vehicle No.: TS15Z0203
# Total OPTD_ KMS: 11514.0
# Unique SERVICE: ['3122' '2712' '9031' '2642' '2782' '9038' '2592' '1622']
# Unique Corridors: [nan 'Vijayawada' 'Others']
# ===
# Vehicle No.: TS15Z0211
# Total OPTD_ KMS: 13103.0
# Unique SERVICE: ['2592' '2582' '3122' '9036' '2782' '2722' '9035' '1752' '9034' '2642'
#  '2652' '2732']
# Unique Corridors: ['Others' nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0218
# Total OPTD_ KMS: 11644.0
# Unique SERVICE: ['2712' '2652' '2782' '2792' '2662' '2642' '9033' '3122' '2612' '9032']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0221
# Total OPTD_ KMS: 9350.0
# Unique SERVICE: ['9506' '9507' '3112' '1732' '2642' '2712' '2592' '9035' '3102']
# Unique Corridors: [nan 'Vijayawada' 'Others']
# ===
# Vehicle No.: TS15Z0223
# Total OPTD_ KMS: 9044.0
# Unique SERVICE: ['3102' '3112' '9507' '3122' '2702' '9036' '9037' '9032' '2712']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0224
# Total OPTD_ KMS: 14300.0
# Unique SERVICE: ['2712' '1752' '2782' '3112' '9036' '3102' '3122' '2642']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0228
# Total OPTD_ KMS: 9301.0
# Unique SERVICE: ['3112' '3102' '3122' '2712' '9036' '9034']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0229
# Total OPTD_ KMS: 14062.0
# Unique SERVICE: ['2582' '2592' '2712' '2942']
# Unique Corridors: ['Others' 'Vijayawada']
# ===
# Vehicle No.: TS15Z0230
# Total OPTD_ KMS: 8961.0
# Unique SERVICE: ['3112' '3102' '9032' '2642' '2732' '2662' '2712']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0231
# Total OPTD_ KMS: 7943.0
# Unique SERVICE: ['1752' '2712' '3122' '3112' '3102' '9038' '2792']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0232
# Total OPTD_ KMS: 12115.0
# Unique SERVICE: ['3122' '2642' '2652' '2662' '2782' '2792' '2632' '2592' '2862' '2732'
#  '2712' '3102' '1752']
# Unique Corridors: [nan 'Vijayawada' 'Others']
# ===
# Vehicle No.: TS16Z0172
# Total OPTD_ KMS: 2964.0
# Unique SERVICE: ['223' 'GV02' 'RJV9' '2201']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS21Z0018
# Total OPTD_ KMS: 10822.0
# Unique SERVICE: ['RC49' 'GLB3' 'RC20' 'MTM4' 'RC51' 'MTM5' 'GLB6' 'YGR5' '9002' 'RC18'
#  '9501' 'RC53' 'RC26' 'RCR7' '9051' 'YGR8' 'YGR2' '9003' '9001']
# Unique Corridors: ['Bangalore' 'Others' 'Bangalore (200 km)' nan]
# ===
# Vehicle No.: TS21Z0025
# Total OPTD_ KMS: 12052.0
# Unique SERVICE: ['SDM1' 'MTM4' 'YGR5' '9501' 'RC01' '9008' 'YGR8' 'RC53' 'RC51' 'YGR2'
#  'RC49']
# Unique Corridors: ['Others' 'Bangalore' 'Bangalore (200 km)' nan]
# ===
# Vehicle No.: TS21Z0043
# Total OPTD_ KMS: 11586.0
# Unique SERVICE: ['GLB4' 'MTM1' 'RCR7' 'MTM4' 'RC49' 'RC15' '9002' 'SDM1' '9007' '9011'
#  'RC53' 'RC46' '9001' '9005']
# Unique Corridors: ['Others' 'Bangalore' nan]
# ===
# Vehicle No.: TS29Z0031
# Total OPTD_ KMS: 14630.0
# Unique SERVICE: ['2181' '223' '304' '2161' '212' '317' '224' '2261' '1511' '1601' '1551'
#  'RJV1' 'GV02' '9025' 'GV05' '9011' '2251' 'RJV9']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS29Z0032
# Total OPTD_ KMS: 13081.0
# Unique SERVICE: ['211' '1601' '2261' '2271' 'RJV2' '9022' 'RJV8' 'RJV6' '9028' 'GV07'
#  'GV05' '2171']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS31Z0049
# Total OPTD_ KMS: 12228.0
# Unique SERVICE: ['SDM3' 'MTM5' '9003' 'RCR7' 'RC15' 'YGR2' 'GLB3' 'RC26' 'GLB5' 'RC01'
#  '9002' 'RC51' 'RC37']
# Unique Corridors: ['Others' 'Bangalore' nan 'Bangalore (200 km)']
# ===
# Vehicle No.: TS31Z0050
# Total OPTD_ KMS: 9358.0
# Unique SERVICE: ['YGR5' 'YGR7' 'YGR2' 'RC51' 'BCK4' '9003' 'SDM1' 'RC35' 'GLB6' 'MTM4'
#  'BCK3' 'RC37' 'SDM3' 'MTM5']
# Unique Corridors: ['Bangalore (200 km)' 'Bangalore' 'Others' nan]
# ===
# Vehicle No.: TS34Z0018
# Total OPTD_ KMS: 11028.0
# Unique SERVICE: ['9002' 'RC49' 'YGR8' 'GLB6' 'RC26' 'RCR7' '9010' '9004' 'RC15' 'RC51'
#  'GLB1' 'RC20' '9001' 'YGR2' 'SDM4' 'YGR1']
# Unique Corridors: [nan 'Bangalore' 'Bangalore (200 km)' 'Others']
# ===
# Vehicle No.: TS34Z0019
# Total OPTD_ KMS: 10598.0
# Unique SERVICE: ['RCR7' 'YGR8' 'SEDM' 'SDM2' 'SDM3' 'YGR7' 'BCK4' 'RC46' 'RC26' '9003'
#  '9004' 'RC18' 'RC35' 'GLB5' 'MTM4' 'SDM4']
# Unique Corridors: ['Bangalore' 'Bangalore (200 km)' 'Others' nan]
# ===
# Vehicle No.: TS34Z0020
# Total OPTD_ KMS: 9640.0
# Unique SERVICE: ['SDM1' 'SDM3' 'SEDM' 'SDM2' 'SDM4' 'GLB3']
# Unique Corridors: ['Others']
# ===
# Vehicle No.: TS34Z0021
# Total OPTD_ KMS: 1530.0
# Unique SERVICE: ['SDM2' '9505' 'SDM4' '9004']
# Unique Corridors: ['Others' nan]
# ===
# Vehicle No.: TS34Z0022
# Total OPTD_ KMS: 10464.0
# Unique SERVICE: ['MTM1' 'RC51' '9003' 'BCK3' 'SDM3' 'SDM1' 'YGR2' 'RC46' 'YGR5' 'YGR8'
#  'RC01' 'RC15' 'RC18' 'MTM4' '9015' '9002']
# Unique Corridors: ['Bangalore' nan 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS34Z0023
# Total OPTD_ KMS: 13416.0
# Unique SERVICE: ['SDM4' 'GLB5' 'GLB4' '9001' 'YGR8' 'YGR5' '9003' 'MTM4' 'MTM5' 'GLB3'
#  'RC20' 'GLB1']
# Unique Corridors: ['Others' nan 'Bangalore (200 km)' 'Bangalore']
# ===
# Vehicle No.: TS36Z0037
# Total OPTD_ KMS: 10366.0
# Unique SERVICE: ['BCK4' '9021' '9003' 'RC35' 'SDM4' '9001' 'SDM1' 'RC15' 'RC51' 'GLB5'
#  'RC18' 'YGR8']
# Unique Corridors: ['Others' nan 'Bangalore' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS36Z0038
# Total OPTD_ KMS: 9096.0
# Unique SERVICE: ['BCK3' 'SDM2' 'YGR8' 'SDM3' 'GLB1' 'BCK4' 'RC51' 'MTM5' 'SDM1' 'SDM4']
# Unique Corridors: ['Others' 'Bangalore (200 km)' 'Bangalore']
# ===
# Vehicle No.: TSAAZ0290
# Total OPTD_ KMS: 870.0
# Unique SERVICE: ['DG']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS05Z0171
# Total OPTD_ KMS: 16361.0
# Unique SERVICE: ['2962' '1632' '2852' '3022' '2942' '2932' '2862' '1832' '2832' '2922'
#  '2972' '3012' '1652']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS05Z0176
# Total OPTD_ KMS: 10620.0
# Unique SERVICE: ['2251' '2261' '2181' '2191' 'RJV9' '1601' 'RJV6' '1511' '2271']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4070
# Total OPTD_ KMS: 12270.0
# Unique SERVICE: ['2872' '3032' '2842' '3002' '1622']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4072
# Total OPTD_ KMS: 12296.0
# Unique SERVICE: ['2872' '3032' '1622' '3002' '9055']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4073
# Total OPTD_ KMS: 15070.0
# Unique SERVICE: ['1622' '9052' '3002' '2842' '2872' '2942' '2932' '2972' '3032' '1732']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4074
# Total OPTD_ KMS: 14215.0
# Unique SERVICE: ['2842' '3002' '2872' '3032' '1632' '1622' '1712' '9045' '9052' '2862'
#  '3022']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4075
# Total OPTD_ KMS: 14237.0
# Unique SERVICE: ['ADB7' 'ADB6' 'ADB5' 'ADB4' '9052']
# Unique Corridors: ['Adilabad' nan]
# ===
# Vehicle No.: TS07Z4076
# Total OPTD_ KMS: 3838.0
# Unique SERVICE: ['GV07' 'GV06' '301' 'RJV7' 'GBC2' '9011']
# Unique Corridors: ['Vijayawada' '0' nan]
# ===
# Vehicle No.: TS07Z4083
# Total OPTD_ KMS: 17192.0
# Unique SERVICE: ['ADB6' 'ADB5' 'ADB4' 'ADB7']
# Unique Corridors: ['Adilabad']
# ===
# Vehicle No.: TS07Z4085
# Total OPTD_ KMS: 14918.0
# Unique SERVICE: ['GV02' 'GV03' 'GV04' 'GV07' '2131' 'GV01' 'GBC4' 'RJV3']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS07Z4086
# Total OPTD_ KMS: 16598.0
# Unique SERVICE: ['GV03' '301' '323' 'GBC1' 'RJV7' 'GBC5' 'GV04' 'GBC3' 'GBC2']
# Unique Corridors: ['Vijayawada' '0' nan]
# ===
# Vehicle No.: TS07Z4089
# Total OPTD_ KMS: 16856.0
# Unique SERVICE: ['3002' '2842' '2872' '2972' '1622' '3032']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS07Z4111
# Total OPTD_ KMS: 16551.0
# Unique SERVICE: ['ADB4' 'ADB6' 'ADB7' 'BNGC' 'BNGE' 'ADB5']
# Unique Corridors: ['Adilabad' 'Bangalore']
# ===
# Vehicle No.: TS07Z4113
# Total OPTD_ KMS: 11261.5
# Unique SERVICE: ['ADB4' 'ADB5' 'ADB7' '9051' 'BNGC' 'ADB6' 'BNGD']
# Unique Corridors: ['Adilabad' nan 'Bangalore']
# ===
# Vehicle No.: TS08Z0066
# Total OPTD_ KMS: 4512.0
# Unique SERVICE: ['2171' '9011' '2271' 'GV07' 'GV05' '2251' '2181']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0070
# Total OPTD_ KMS: 16734.0
# Unique SERVICE: ['322' '9025' '323' 'GV02' 'GBC2' 'GV04' 'GBC3' 'RJV3' '1541' 'GBC5']
# Unique Corridors: ['0' nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0071
# Total OPTD_ KMS: 14495.0
# Unique SERVICE: ['324' '325' 'GBC4' 'GBC5' 'GBC3' '9011' 'GV04' '3302']
# Unique Corridors: ['0' nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0114
# Total OPTD_ KMS: 10053.0
# Unique SERVICE: ['224' 'RJV2' 'RJV3' '2171' 'RJV4' '2181' 'RJV6' '2251' '9028' '2191'
#  'GV02' 'RJV5']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0115
# Total OPTD_ KMS: 16660.0
# Unique SERVICE: ['1541' '2161' '321' '211' '212' 'RJV7' '2201' '2191' '2181' '2251' 'GV07'
#  'GV06' 'RJV9' 'RJV6' 'RJV8' '2271']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0126
# Total OPTD_ KMS: 12729.0
# Unique SERVICE: ['3012' '3022' '2942' '2922' '2852' '1652' '2832' '1832' '1732' '3052'
#  '2882' '9042']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0149
# Total OPTD_ KMS: 3048.0
# Unique SERVICE: ['2171' '1541' '317' '2251' 'GV07' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0154
# Total OPTD_ KMS: 12502.0
# Unique SERVICE: ['2131' '2171' '304' '9011' '2181' '1551' '2261' '1511' 'GV05' 'RJV5'
#  '2191' 'GV02' 'GV06']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0155
# Total OPTD_ KMS: 10742.0
# Unique SERVICE: ['224' '9011' 'RJV1' '2261' '1551' '2201' '2161' 'RJV5' 'GV02' 'GV06'
#  'GV07' '2171']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0159
# Total OPTD_ KMS: 15382.0
# Unique SERVICE: ['2161' '2191' '321' '304' '1511' '1601' '2271' 'RJV6' '2201' 'RJV8'
#  '2181' 'GV06' 'GV02' '2261' 'RJV2']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0160
# Total OPTD_ KMS: 5830.0
# Unique SERVICE: ['2191' '2271' '9011' 'RJV9' '2201' 'RJV1' '1511' 'RJV2']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0202
# Total OPTD_ KMS: 10800.0
# Unique SERVICE: ['GV04' 'GV05' 'GV02' 'GV01' 'GV03' 'RJV3' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0203
# Total OPTD_ KMS: 3980.0
# Unique SERVICE: ['9011' 'GV03' 'RJV3' 'RJV7' '9005']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS08Z0204
# Total OPTD_ KMS: 12762.0
# Unique SERVICE: ['GV01' 'GV02' 'GV07' '1541' 'GV03' 'RJV3' 'GBC4' 'GBC5' 'RJV7']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0205
# Total OPTD_ KMS: 9742.0
# Unique SERVICE: ['301' '212' 'GV07' 'GV03' '9011' 'GBC1' '1541' 'GV04' '2131']
# Unique Corridors: ['0' 'Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0206
# Total OPTD_ KMS: 14428.0
# Unique SERVICE: ['GV05' 'GV04' 'GV01' 'GV06' 'RJV3' '9011' '1541' 'GBC4' 'GBC5']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0209
# Total OPTD_ KMS: 9053.0
# Unique SERVICE: ['3302' '315' 'GB08' 'RJV7']
# Unique Corridors: ['Vijayawada' 'Bangalore' nan]
# ===
# Vehicle No.: TS08Z0210
# Total OPTD_ KMS: 12360.0
# Unique SERVICE: ['1622' '1652' '1632' '2842' '3002' '3102' '3032']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0211
# Total OPTD_ KMS: 15321.0
# Unique SERVICE: ['GV03' 'GV06' 'GV07' 'GV04' 'GV02' 'GV05' 'RJV3' 'GBC5' '9026' 'GBC3'
#  '9030' '1541' 'GBC1']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0212
# Total OPTD_ KMS: 12572.0
# Unique SERVICE: ['315' 'GB08' 'RJV7' 'GBC5' '9001' 'GBC1' 'GBC3']
# Unique Corridors: ['Bangalore' nan]
# ===
# Vehicle No.: TS08Z0213
# Total OPTD_ KMS: 17592.0
# Unique SERVICE: ['9501' '323' '9028' 'GV07' '2161' 'GBC3' 'GBC5' 'GBC4' 'GV04' '9023'
#  'GBC2' '9027' '2131']
# Unique Corridors: [nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS08Z0214
# Total OPTD_ KMS: 440.0
# Unique SERVICE: ['1652' '1622']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0215
# Total OPTD_ KMS: 11528.0
# Unique SERVICE: ['GBC2' 'GBC1' 'GM09']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS08Z0216
# Total OPTD_ KMS: 10556.0
# Unique SERVICE: ['323' '3302' 'GB08']
# Unique Corridors: ['0' 'Vijayawada' nan]
# ...
# ===
# Vehicle No.: TS08Z0278
# Total OPTD_ KMS: 12336.0
# Unique SERVICE: ['GLB1' '9002' 'RC26' 'SDM1' 'RC01' 'MTM5' 'RC46' 'BCK4' 'RCR7' 'RC18'
#  'RC35' 'RC49' 'RC15' 'GLB5' 'GLB4']
# Unique Corridors: ['Others' nan 'Bangalore']
# ===
# Vehicle No.: TS08Z0283
# Total OPTD_ KMS: 10648.0
# Unique SERVICE: ['MTM5' 'RC26' 'RC53' 'RC46' 'SDM1' 'YGR8' 'RC01' 'RC18' 'MTM4' 'RC15'
#  'GLB3' 'SDM3' 'RC37' 'RCR7']
# Unique Corridors: ['Bangalore' 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0284
# Total OPTD_ KMS: 5987.0
# Unique SERVICE: ['2642' '2612' '2632' '3012' '2702' '1712' '9031' '2732' '2622' '2972']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0285
# Total OPTD_ KMS: 4720.0
# Unique SERVICE: ['1961' '2542' '2051' '2522' '2002' '2222']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0286
# Total OPTD_ KMS: 12030.0
# Unique SERVICE: ['GLB6' 'RC15' 'MTM5' 'RC26' 'RC20' 'YGR2' 'BCK3' 'GLB3' 'GLB1' 'RC51'
#  'RC35' 'RC37' 'YGR7' 'RCR7' 'GLB5' 'MTM4' 'RC46' 'GLB4']
# Unique Corridors: ['Others' 'Bangalore' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0287
# Total OPTD_ KMS: 8556.0
# Unique SERVICE: ['MTM4' 'RC01' 'BCK3' 'SDM4' 'RC18' 'RC15' '9006' 'YGR7' 'RC35' 'RC46'
#  'RC40' 'MTM5' 'RC37' 'MTY2']
# Unique Corridors: ['Bangalore' 'Others' nan 'Bangalore (200 km)']
# ===
# Vehicle No.: TS08Z0288
# Total OPTD_ KMS: 11365.0
# Unique SERVICE: ['2792' '2652' '2612' '9031' '2632' '2642' '2722' '9033' '2622' '1732'
#  '2702' '2852']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0289
# Total OPTD_ KMS: 3426.0
# Unique SERVICE: ['RC46' 'YGR8' 'YGR7' 'RC01' '9003' 'YGR5' 'GLB1']
# Unique Corridors: ['Bangalore' 'Bangalore (200 km)' nan 'Others']
# ===
# Vehicle No.: TS08Z0290
# Total OPTD_ KMS: 8310.0
# Unique SERVICE: ['2532' '2092' '9011' '2102' '1961' '2222' '7771' '2051' '2202' '1992'
#  '2522' '2041']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS08Z0291
# Total OPTD_ KMS: 5900.0
# Unique SERVICE: ['2051' '2552' '2002' '2222' '2522' '2512' '2082']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS08Z0292
# Total OPTD_ KMS: 7968.0
# Unique SERVICE: ['SLP2' 'KRN1' 'NDL5' '9009' 'NDL2' '9010' '9005']
# Unique Corridors: ['Others' 'Bangalore' nan]
# ===
# Vehicle No.: TS09Z7609
# Total OPTD_ KMS: 2016.0
# Unique SERVICE: ['1732' '2942' '2952' '1712']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7621
# Total OPTD_ KMS: 14806.0
# Unique SERVICE: ['1601' '211' '2261' '1511' '1551' '9011' 'RJV3' '2131' 'GV02' 'RJV2'
#  'RJV1' '2181' '2191' 'RJV8' 'GV07' 'RJV6' '2201']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7622
# Total OPTD_ KMS: 4340.0
# Unique SERVICE: ['2191' '1601' '2271' 'RJV5' 'RJV9' '9023' '2161' '9011']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7642
# Total OPTD_ KMS: 12351.0
# Unique SERVICE: ['1551' '270' '271' '2251' '2171' 'RJV3' 'RJV4' '2161' 'GV05' 'RJV6'
#  '2271' '1511' '9501' 'RJV5']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7682
# Total OPTD_ KMS: 16856.0
# Unique SERVICE: ['1622' '2962' '2912' '2842' '3052' '1642' '2922' '2952' '1632' '2832'
#  '2992' '3012' '1732' '2852']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7791
# Total OPTD_ KMS: 1140.0
# Unique SERVICE: ['9011']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS09Z7809
# Total OPTD_ KMS: 1010.0
# Unique SERVICE: ['CH']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS09Z7848
# Total OPTD_ KMS: 620.0
# Unique SERVICE: ['JP']
# Unique Corridors: [nan]
# ===
# Vehicle No.: TS09Z7871
# Total OPTD_ KMS: 15122.0
# Unique SERVICE: ['9008' 'ADN2' '9009' 'NDL1' 'NDL2' 'KRNL' '9050' 'NDL5' '9010' 'ADN1']
# Unique Corridors: [nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7881
# Total OPTD_ KMS: 13665.0
# Unique SERVICE: ['AMVY' 'MKP2' '9004' 'ADN2' 'NGPM' 'ADN1' 'NDL5' 'NDL1' '9022' 'KRNL'
#  '9011' '9005' '9023' 'KRN1' 'NDL3']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7882
# Total OPTD_ KMS: 17553.5
# Unique SERVICE: ['ADN1' 'AMVY' 'ADN2' '9004' 'NGP2' '9502' 'SLP2']
# Unique Corridors: ['Bangalore' '0' nan 'Others']
# ===
# Vehicle No.: TS09Z7890
# Total OPTD_ KMS: 15100.0
# Unique SERVICE: ['2041' '2051' '2022' '2512' '2542' '4441' '2082' '1961' '2072' '2092'
#  '2532' '3331' '9502' '2222']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7891
# Total OPTD_ KMS: 14456.0
# Unique SERVICE: ['4441' '2542' '2202' '3331' '2082' '1961' '2072' '6661' '2522' '2092'
#  '9022' '2022' '2051' '2102' 'RJV6']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7892
# Total OPTD_ KMS: 4720.0
# Unique SERVICE: ['2041' '3331' '2082' '2102' '2092' '2532']
# Unique Corridors: ['Vijayawada']
# ===
# Vehicle No.: TS09Z7897
# Total OPTD_ KMS: 15168.0
# Unique SERVICE: ['NDL1' 'PDP1' 'NDL4' '9022' 'RPR1' 'VJA2' 'NDL2' '9015' 'NDL5' 'NDL3'
#  'KRNL' 'MKP2' '9001' 'ADN1' 'ADN2']
# Unique Corridors: ['Bangalore' 'Vijayawada (140 km)' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7898
# Total OPTD_ KMS: 17324.0
# Unique SERVICE: ['1931' '7771' '2522' '2002' '2222' '2041' '6661' '2102' '1992' '9030'
#  '2552' '1961' '3331']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7902
# Total OPTD_ KMS: 13794.0
# Unique SERVICE: ['NDL2' 'KRN1' 'KRNL' 'NDL4' 'SLP2' 'NDL5' 'NDL1' '9006' '9021']
# Unique Corridors: ['Bangalore' 'Others' nan]
# ===
# Vehicle No.: TS09Z7909
# Total OPTD_ KMS: 9867.0
# Unique SERVICE: ['2322' '2302']
# Unique Corridors: ['Vijayawada' 'Bangalore']
# ===
# Vehicle No.: TS09Z7910
# Total OPTD_ KMS: 9423.0
# Unique SERVICE: ['314' '2312']
# Unique Corridors: ['Bangalore']
# ===
# Vehicle No.: TS09Z7912
# Total OPTD_ KMS: 13616.0
# Unique SERVICE: ['2542' '2092' '2041' '2222' '2022' '6661' '2202' '2512' '2082' '3331'
#  '2072' 'SB01' '1931' '1961' '2061']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7913
# Total OPTD_ KMS: 15934.0
# Unique SERVICE: ['7771' '2222' '1931' '2041' '2202' '2512' '2061' '2532' '2002' '4441'
#  '1992' '9022' '1961' 'SB01' '9027' '9511' '2092' '9026' '2552' '3331'
#  '2082']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7915
# Total OPTD_ KMS: 15433.0
# Unique SERVICE: ['3331' '2082' '1961' '2061' '4441' '2522' '9023' '6661' '2002' '2102'
#  '2542' '9025' '9020' '2532' '2072']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7916
# Total OPTD_ KMS: 14554.0
# Unique SERVICE: ['2222' '1961' '2552' '4441' '2522' '2002' '6661' '2041' '1931' '7771'
#  '9501' '2022' '9004' '2072' '2202' '2512' '2051']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7917
# Total OPTD_ KMS: 15940.0
# Unique SERVICE: ['SB01' '2072' '2061' '2512' '2002' '2522' '2092' '2532' '3331' 'RJV5'
#  '1992' '9022' '9501' '7771' '6661' '2041' '9026' '2022']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS09Z7918
# Total OPTD_ KMS: 17262.0
# Unique SERVICE: ['9022' 'MKP1' 'MKP2']
# Unique Corridors: [nan '0']
# ===
# Vehicle No.: TS09Z7919
# Total OPTD_ KMS: 17034.0
# Unique SERVICE: ['MKP1' 'MKP2' '9022' '9002' 'NDL5' 'KRNL']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7920
# Total OPTD_ KMS: 10258.0
# Unique SERVICE: ['2322' '2312' '2302']
# Unique Corridors: ['Vijayawada' 'Bangalore']
# ===
# Vehicle No.: TS09Z7921
# Total OPTD_ KMS: 10414.0
# Unique SERVICE: ['314' '2322' '2312' '2292']
# Unique Corridors: ['Bangalore' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7922
# Total OPTD_ KMS: 9020.0
# Unique SERVICE: ['2302' '314' 'ASB1' '9011' '2292' '2322']
# Unique Corridors: ['Bangalore' nan 'Vijayawada']
# ===
# Vehicle No.: TS09Z7925
# Total OPTD_ KMS: 15901.0
# Unique SERVICE: ['2102' '2002' '2092' '2542' '1992' '1931' '3331' '2061' '2202' '2051'
#  '2022' '7771' '6661' '9023' '2512' '2532' '1961' '2072']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7935
# Total OPTD_ KMS: 14619.0
# Unique SERVICE: ['2022' '2061' '2072' '2202' '3331' '2102' '1992' '2002' '2512' '2082'
#  'SB01' '9029' '9023' '2532' '6661']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7938
# Total OPTD_ KMS: 8453.0
# Unique SERVICE: ['SB01' '9020' '2532']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS09Z7941
# Total OPTD_ KMS: 10454.0
# Unique SERVICE: ['PDP1' '9005' '9011' 'NGP2' 'SLP2']
# Unique Corridors: ['Vijayawada (140 km)' nan '0' 'Others']
# ===
# Vehicle No.: TS09Z7945
# Total OPTD_ KMS: 11602.5
# Unique SERVICE: ['NGP2' 'PDP1' 'NGPM' 'AMVY' '9023' '9008' '9014' 'KRNL' '9009' 'RPR1']
# Unique Corridors: ['0' 'Vijayawada (140 km)' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7946
# Total OPTD_ KMS: 10998.5
# Unique SERVICE: ['RPR1' 'AMVY' 'NGP2' 'ADN1' 'NGPM' 'KRNL' '9024']
# Unique Corridors: ['0' 'Bangalore' nan]
# ===
# Vehicle No.: TS09Z7947
# Total OPTD_ KMS: 15122.0
# Unique SERVICE: ['MKP2' 'PDP1' 'SLP2' '9006' 'RPR1' '9010' '9021' '9008' '9001' 'NDL1'
#  '9022' 'NDL3' 'KRN1']
# Unique Corridors: ['0' 'Vijayawada (140 km)' 'Others' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7956
# Total OPTD_ KMS: 9590.0
# Unique SERVICE: ['1961' 'SB01' '9023']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7957
# Total OPTD_ KMS: 10526.0
# Unique SERVICE: ['AMVY' 'NDL3' 'NDL5' 'NDL4' 'PDP1' '9009' '9015' '9006' 'NGPM' 'ADN2'
#  '9021' '9005' '9011']
# Unique Corridors: ['0' 'Bangalore' 'Vijayawada (140 km)' nan]
# ===
# Vehicle No.: TS09Z7958
# Total OPTD_ KMS: 12926.0
# Unique SERVICE: ['NDL5' 'NDL4' 'NDL1' 'KRN1' '9009' '9012' 'NDL2' '9010' 'NDL3' 'KRNL'
#  'RPR1' 'MKP2' 'VJA2' 'AMVY' '9011' '9002']
# Unique Corridors: ['Bangalore' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7960
# Total OPTD_ KMS: 12371.5
# Unique SERVICE: ['NGPM' 'RPR1' '9003' 'ADN1' '9009' 'NGP2' 'NDL5' 'NDL1' '9012' '9021'
#  '9023']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7961
# Total OPTD_ KMS: 10830.5
# Unique SERVICE: ['NGPM' 'RPR1' 'AMVY' 'NGP2' '9010' 'MKP2' 'PDP1']
# Unique Corridors: ['0' nan 'Vijayawada (140 km)']
# ===
# Vehicle No.: TS09Z7962
# Total OPTD_ KMS: 10844.0
# Unique SERVICE: ['NGP2' 'NGPM' 'RPR1' '9015' 'NDL4' '9051' '9054']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7963
# Total OPTD_ KMS: 9775.5
# Unique SERVICE: ['RPR1' '9010' 'NDL4' '9006' 'NGP2' '9021' 'NGPM']
# Unique Corridors: ['0' nan 'Bangalore']
# ===
# Vehicle No.: TS09Z7964
# Total OPTD_ KMS: 15913.0
# Unique SERVICE: ['2072' '2202' '6661' '7771' '2051' '2512' '2022' '2222' '2041' '9026'
#  '2061' '3331' 'SB01']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS09Z7972
# Total OPTD_ KMS: 14909.0
# Unique SERVICE: ['VJA2' 'ADN1' 'NDL4' '9005' '9010' 'ADN2' 'NDL2']
# Unique Corridors: ['Vijayawada' 'Bangalore' nan]
# ===
# Vehicle No.: TS09Z7973
# Total OPTD_ KMS: 14226.0
# Unique SERVICE: ['NDL3' '9008' 'NDL2' '9004' '9021' 'AMVY' 'NDL1' '9009' '9051' '9007'
#  'VJA2' '9006' '9010']
# Unique Corridors: ['Bangalore' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7976
# Total OPTD_ KMS: 11952.0
# Unique SERVICE: ['ADN2' '9006' '9004' 'ADN1' 'NDL3' 'NDL2' 'NDL4' '9009' 'NGPM' 'RPR1'
#  'VJA2' 'KRNL']
# Unique Corridors: ['Bangalore' nan '0' 'Vijayawada']
# ===
# Vehicle No.: TS09Z7977
# Total OPTD_ KMS: 14956.0
# Unique SERVICE: ['NDL4' 'NDL2' 'NDL3' 'KRN1' 'ADN1' 'NGPM' 'RPR1' '9008' '9013' 'NDL1']
# Unique Corridors: ['Bangalore' '0' nan]
# ===
# Vehicle No.: TS09Z7979
# Total OPTD_ KMS: 10280.0
# Unique SERVICE: ['9005' 'KRNL' 'NDL3' 'PDP1' 'KRN1' 'ADN1' '9021' 'NDL4' 'AMVY' 'NGPM'
#  'NDL1']
# Unique Corridors: [nan 'Bangalore' 'Vijayawada (140 km)' '0']
# ===
# Vehicle No.: TS09Z7980
# Total OPTD_ KMS: 14036.0
# Unique SERVICE: ['NDL2' 'NDL1' '9008' '9007' 'NDL4' 'NDL3' 'KRNL' 'SLP2' '9501' '9011'
#  '9024' '9021' 'MKP2' 'MKP1' '9009']
# Unique Corridors: ['Bangalore' nan 'Others' '0']
# ===
# Vehicle No.: TS15Z0211
# Total OPTD_ KMS: 13103.0
# Unique SERVICE: ['2592' '2582' '3122' '9036' '2782' '2722' '9035' '1752' '9034' '2642'
#  '2652' '2732']
# Unique Corridors: ['Others' nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0218
# Total OPTD_ KMS: 11644.0
# Unique SERVICE: ['2712' '2652' '2782' '2792' '2662' '2642' '9033' '3122' '2612' '9032']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0221
# Total OPTD_ KMS: 9350.0
# Unique SERVICE: ['9506' '9507' '3112' '1732' '2642' '2712' '2592' '9035' '3102']
# Unique Corridors: [nan 'Vijayawada' 'Others']
# ===
# Vehicle No.: TS15Z0223
# Total OPTD_ KMS: 9044.0
# Unique SERVICE: ['3102' '3112' '9507' '3122' '2702' '9036' '9037' '9032' '2712']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0224
# Total OPTD_ KMS: 14300.0
# Unique SERVICE: ['2712' '1752' '2782' '3112' '9036' '3102' '3122' '2642']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0228
# Total OPTD_ KMS: 9301.0
# Unique SERVICE: ['3112' '3102' '3122' '2712' '9036' '9034']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0229
# Total OPTD_ KMS: 14062.0
# Unique SERVICE: ['2582' '2592' '2712' '2942']
# Unique Corridors: ['Others' 'Vijayawada']
# ===
# Vehicle No.: TS15Z0230
# Total OPTD_ KMS: 8961.0
# Unique SERVICE: ['3112' '3102' '9032' '2642' '2732' '2662' '2712']
# Unique Corridors: [nan 'Vijayawada']
# ===
# Vehicle No.: TS15Z0231
# Total OPTD_ KMS: 7943.0
# Unique SERVICE: ['1752' '2712' '3122' '3112' '3102' '9038' '2792']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS15Z0232
# Total OPTD_ KMS: 12115.0
# Unique SERVICE: ['3122' '2642' '2652' '2662' '2782' '2792' '2632' '2592' '2862' '2732'
#  '2712' '3102' '1752']
# Unique Corridors: [nan 'Vijayawada' 'Others']
# ===
# Vehicle No.: TS16Z0172
# Total OPTD_ KMS: 2964.0
# Unique SERVICE: ['223' 'GV02' 'RJV9' '2201']
# Unique Corridors: ['Vijayawada' nan]
# ===
# Vehicle No.: TS21Z0018
# Total OPTD_ KMS: 10822.0
# Unique SERVICE: ['RC49' 'GLB3' 'RC20' 'MTM4' 'RC51' 'MTM5' 'GLB6' 'YGR5' '9002' 'RC18'
#  '9501' 'RC53' 'RC26' 'RCR7' '9051' 'YGR8' 'YGR2' '9003' '9001']
# Unique Corridors: ['Bangalore' 'Others' 'Bangalore (200 km)' nan]
# ===
# Vehicle No.: TS21Z0025
# Total OPTD_ KMS: 12052.0
# Unique SERVICE: ['SDM1' 'MTM4' 'YGR5' '9501' 'RC01' '9008' 'YGR8' 'RC53' 'RC51' 'YGR2'
#  'RC49']
# Unique Corridors: ['Others' 'Bangalore' 'Bangalore (200 km)' nan]
# ===
# Vehicle No.: TS21Z0043
# Total OPTD_ KMS: 11586.0
# Unique SERVICE: ['GLB4' 'MTM1' 'RCR7' 'MTM4' 'RC49' 'RC15' '9002' 'SDM1' '9007' '9011'
#  'RC53' 'RC46' '9001' '9005']
# Unique Corridors: ['Others' 'Bangalore' nan]
# ===
# Vehicle No.: TS31Z0049
# Total OPTD_ KMS: 12228.0
# Unique SERVICE: ['SDM3' 'MTM5' '9003' 'RCR7' 'RC15' 'YGR2' 'GLB3' 'RC26' 'GLB5' 'RC01'
#  '9002' 'RC51' 'RC37']
# Unique Corridors: ['Others' 'Bangalore' nan 'Bangalore (200 km)']
# ===
# Vehicle No.: TS31Z0050
# Total OPTD_ KMS: 9358.0
# Unique SERVICE: ['YGR5' 'YGR7' 'YGR2' 'RC51' 'BCK4' '9003' 'SDM1' 'RC35' 'GLB6' 'MTM4'
#  'BCK3' 'RC37' 'SDM3' 'MTM5']
# Unique Corridors: ['Bangalore (200 km)' 'Bangalore' 'Others' nan]
# ===
# Vehicle No.: TS34Z0018
# Total OPTD_ KMS: 11028.0
# Unique SERVICE: ['9002' 'RC49' 'YGR8' 'GLB6' 'RC26' 'RCR7' '9010' '9004' 'RC15' 'RC51'
#  'GLB1' 'RC20' '9001' 'YGR2' 'SDM4' 'YGR1']
# Unique Corridors: [nan 'Bangalore' 'Bangalore (200 km)' 'Others']
# ===
# Vehicle No.: TS34Z0019
# Total OPTD_ KMS: 10598.0
# Unique SERVICE: ['RCR7' 'YGR8' 'SEDM' 'SDM2' 'SDM3' 'YGR7' 'BCK4' 'RC46' 'RC26' '9003'
#  '9004' 'RC18' 'RC35' 'GLB5' 'MTM4' 'SDM4']
# Unique Corridors: ['Bangalore' 'Bangalore (200 km)' 'Others' nan]
# ===
# Vehicle No.: TS34Z0020
# Total OPTD_ KMS: 9640.0
# Unique SERVICE: ['SDM1' 'SDM3' 'SEDM' 'SDM2' 'SDM4' 'GLB3']
# Unique Corridors: ['Others']
# ===
# Vehicle No.: TS34Z0021
# Total OPTD_ KMS: 1530.0
# Unique SERVICE: ['SDM2' '9505' 'SDM4' '9004']
# Unique Corridors: ['Others' nan]
# ===
# Vehicle No.: TS34Z0022
# Total OPTD_ KMS: 10464.0
# Unique SERVICE: ['MTM1' 'RC51' '9003' 'BCK3' 'SDM3' 'SDM1' 'YGR2' 'RC46' 'YGR5' 'YGR8'
#  'RC01' 'RC15' 'RC18' 'MTM4' '9015' '9002']
# Unique Corridors: ['Bangalore' nan 'Others' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS34Z0023
# Total OPTD_ KMS: 13416.0
# Unique SERVICE: ['SDM4' 'GLB5' 'GLB4' '9001' 'YGR8' 'YGR5' '9003' 'MTM4' 'MTM5' 'GLB3'
#  'RC20' 'GLB1']
# Unique Corridors: ['Others' nan 'Bangalore (200 km)' 'Bangalore']
# ===
# Vehicle No.: TS36Z0037
# Total OPTD_ KMS: 10366.0
# Unique SERVICE: ['BCK4' '9021' '9003' 'RC35' 'SDM4' '9001' 'SDM1' 'RC15' 'RC51' 'GLB5'
#  'RC18' 'YGR8']
# Unique Corridors: ['Others' nan 'Bangalore' 'Bangalore (200 km)']
# ===
# Vehicle No.: TS36Z0038
# Total OPTD_ KMS: 9096.0
# Unique SERVICE: ['BCK3' 'SDM2' 'YGR8' 'SDM3' 'GLB1' 'BCK4' 'RC51' 'MTM5' 'SDM1' 'SDM4']
# Unique Corridors: ['Others' 'Bangalore (200 km)' 'Bangalore']
# ===
# Vehicle No.: TSAAZ0290
# Total OPTD_ KMS: 870.0
# Unique SERVICE: ['DG']
# Unique Corridors: [nan]
# ===
