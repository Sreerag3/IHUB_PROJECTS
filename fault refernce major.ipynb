# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreerag3/IHUB_PROJECTS/blob/main/fault%20refernce%20major.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('/content/Raw data Iraste.csv')
print(data.shape)
data.head()
# Out:
# (47716, 45)
#     startDate startTime     endDate   endTime  VehicleNum     vehicleModel  \
# 0  01-07-2023  05:58:54  01-07-2023  06:22:28  MH40BG2596     Eicher 10.75
# 1  01-07-2023  05:29:48  01-07-2023  05:44:47  MH40BG2596     Eicher 10.75
# 2  01-07-2023  06:06:08  01-07-2023  06:35:20  MH40BG7476     Eicher 10.75
# 3  01-07-2023  06:14:58  01-07-2023  06:33:28  MH40BG1535  Tata LP09.6 BS3
# 4  01-07-2023  05:35:59  01-07-2023  05:45:49  MH40BG1535  Tata LP09.6 BS3
#
#              groupName              driverName  StartLatGPS  StartLongGPS  \
# 0  Hansa-Aapli-Red-Bus  Rakesh Nandlal Meshram    21.141287     79.079645
# 1  Hansa-Aapli-Red-Bus  Rakesh Nandlal Meshram    21.116420     79.019128
# 2  Hansa-Aapli-Red-Bus         Vivek Choudhari    21.116597     79.013303
# 3  Hansa-Aapli-Red-Bus          Vinod Dehankar    21.140105     79.092358
# 4  Hansa-Aapli-Red-Bus          Vinod Dehankar    21.116942     79.019998
#
# ...

# %%
data.columns
# Out:
# Index(['startDate', 'startTime', 'endDate', 'endTime', 'VehicleNum',
#        'vehicleModel', 'groupName', 'driverName', 'StartLatGPS',
#        'StartLongGPS', 'EndLatGPS', 'EndLongGPS', 'startAddress', 'endAddress',
#        'distance', 'duration', 'fuelConsumed', 'fuelWasted', 'mileage',
#        'me_fcw_count', 'me_dfm_count', 'me_hmw_count', 'me_lldw_count',
#        'me_pcw_count', 'me_pdz_count', 'me_rldw_count', 'me_tao_count',
#        'me_twl_count', 'me_ufcw_count', 'freerun_count', 'hard_brake_count',
#        'hard_curve_count', 'idling_count', 'over_acceleration_count',
#        'speeding_count', 'stoppage_count', 'hard_curving_count',
#        'dms_tampering', 'lm_tao_count', 'dms_driver_drowsy_count',
#        'dms_driver_asleep_count', 'dms_driver_smoking_count',
#        'dms_driver_distracted_count', 'dms_driver_on_phone_count',
#        'dms_no_seat_belt_count'],
#       dtype='object')

# %%
data = data[['endDate', 'VehicleNum', 'groupName', 'driverName', 'distance', 'me_fcw_count', 'me_hmw_count',
             'me_pcw_count', 'me_lldw_count', 'me_rldw_count']]
data.head()
# Out:
#       endDate  VehicleNum            groupName              driverName  \
# 0  01-07-2023  MH40BG2596  Hansa-Aapli-Red-Bus  Rakesh Nandlal Meshram
# 1  01-07-2023  MH40BG2596  Hansa-Aapli-Red-Bus  Rakesh Nandlal Meshram
# 2  01-07-2023  MH40BG7476  Hansa-Aapli-Red-Bus         Vivek Choudhari
# 3  01-07-2023  MH40BG1535  Hansa-Aapli-Red-Bus          Vinod Dehankar
# 4  01-07-2023  MH40BG1535  Hansa-Aapli-Red-Bus          Vinod Dehankar
#
#    distance  me_fcw_count  me_hmw_count  me_pcw_count  me_lldw_count  \
# 0    11.255             0             0             0              0
# 1     7.568             0             0             0              0
# 2    17.364             0             0             0              0
# 3     9.367             0             0             1              1
# 4     7.133             0             0             0              1
#
#    me_rldw_count
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
# start_date = pd.to_datetime('2023-07-03')
# end_date = pd.to_datetime('2023-07-09')

# filtered_df = df[(df['endDate'] >= start_date) | (df['endDate'] <= end_date)]
# filtered_df['endDate'].value_counts()

# %%
df = data.copy()

# %%
from datetime import datetime

def custom_date_parser(date_str):
    return datetime.strptime(date_str, '%d-%m-%Y')

df['endDate'] = df['endDate'].apply(custom_date_parser)
dfs = []


day_list = [(1, 2), (3, 9), (10, 16), (17, 23), (24, 30), (31, 31)]

for day in day_list:

  start_date = datetime(2023, 7, day[0])
  end_date = datetime(2023, 7, day[1])

  mask = (df['endDate'] >= start_date) & (df['endDate'] <= end_date)
  filtered_df = df[mask]

  filtered_df.reset_index(drop=True, inplace=True)
  dfs.append(filtered_df)

# %%
print(dfs[1].shape)
dfs[1] = dfs[1].drop(['MH31EM0397', 'MH40BG1208','MH40BG7476','MH40BG1076','MH31EM0417','MH40BG0841','MH40BG0869','MH40BG3238','MH40BG0870','MH40BG1081','MH40BG1085','MH40BG1209','MH40BG1215','MH40BG7470','MH31EM0391','MH31FC0377','MH31FC0944','MH31EM0392','MH31FC0943','MH31FC0945','MH31FC0946','MH31FC0966','MH31FC0970','MH31FC0980','MH31EM0409','MH40BG1161','MH40AT0460','MH40Y6891','MH40BG2006','MH40BG7436','MH40BG2008'], axis=0)
print(dfs[1].shape)
# Out:
# (10792, 10)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-fcb46442c697> in <cell line: 2>()
#       1 print(dfs[1].shape)
# ----> 2 dfs[1] = dfs[1].drop(['MH31EM0397', 'MH40BG1208','MH40BG7476','MH40BG1076','MH31EM0417','MH40BG0841','MH40BG0869','MH40BG3238','MH40BG0870','MH40BG1081','MH40BG1085','MH40BG1209','MH40BG1215','MH40BG7470','MH31EM0391','MH31FC0377','MH31FC0944','MH31EM0392','MH31FC0943','MH31FC0945','MH31FC0946','MH31FC0966','MH31FC0970','MH31FC0980','MH31EM0409','MH40BG1161','MH40AT0460','MH40Y6891','MH40BG2006','MH40BG7436','MH40BG2008'], axis=0)
#       3 print(dfs[1].shape)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
print(dfs[2].shape)
dfs[2] = dfs[2].drop(['MH40BG0869', 'MH31EM0395','MH40BG1081','MH40BG1209','MH40BG1073','MH40BG1085','MH31EM0396','MH40BG2596','MH40BG7470','MH31EM0397','MH31EM0417','MH40BG1076','MH40BG1208','MH40BG3238','MH40BG1215','MH31EM0391','MH31FC0424','MH31FC0944','MH31FC0943','MH31FC0945','MH31FC0966','MH31FC0980','MH31FC0377','MH31FC0378','MH40BG1549','MH40BG3460','MH31EM0409','MH40BG1161','MH40AT0460','MH40Y6891','MH40BG2006','MH40BG7436','MH40BG2008'], axis=0)
print(dfs[2].shape)
# Out:
# (11141, 10)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-354ad1b0ccb2> in <cell line: 2>()
#       1 print(dfs[2].shape)
# ----> 2 dfs[2] = dfs[2].drop(['MH40BG0869', 'MH31EM0395','MH40BG1081','MH40BG1209','MH40BG1073','MH40BG1085','MH31EM0396','MH40BG2596','MH40BG7470','MH31EM0397','MH31EM0417','MH40BG1076','MH40BG1208','MH40BG3238','MH40BG1215','MH31EM0391','MH31FC0424','MH31FC0944','MH31FC0943','MH31FC0945','MH31FC0966','MH31FC0980','MH31FC0377','MH31FC0378','MH40BG1549','MH40BG3460','MH31EM0409','MH40BG1161','MH40AT0460','MH40Y6891','MH40BG2006','MH40BG7436','MH40BG2008'], axis=0)
#       3 print(dfs[2].shape)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
# ...

# %%
print(dfs[3].shape)
dfs[3] = dfs[3].drop(['MH40BG1083', 'MH40BG0842','MH40BG1085','MH31EM0417','MH40BG1076','MH40BG1208','MH40BG3238','MH31EM0397','MH40BG1215','MH31FC0406','MH31FC0415','MH31FC0947','MH31FC0939','MH31FC0942','MH40BG1543','MH31EM0427','MH40BG2981','MH40BG1548','MH31EM0409','MH40BG1161','MH40BG2006','MH40BG7436','MH40BG7375','MH40BG2008','MH40Y6893','MH40AT0460','MH40Y6891','MH40Y6897'], axis=0)
print(dfs[3].shape)
# Out:
# (10861, 10)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-8086d3862369> in <cell line: 2>()
#       1 print(dfs[3].shape)
# ----> 2 dfs[3] = dfs[3].drop(['MH40BG1083', 'MH40BG0842','MH40BG1085','MH31EM0417','MH40BG1076','MH40BG1208','MH40BG3238','MH31EM0397','MH40BG1215','MH31FC0406','MH31FC0415','MH31FC0947','MH31FC0939','MH31FC0942','MH40BG1543','MH31EM0427','MH40BG2981','MH40BG1548','MH31EM0409','MH40BG1161','MH40BG2006','MH40BG7436','MH40BG7375','MH40BG2008','MH40Y6893','MH40AT0460','MH40Y6891','MH40Y6897'], axis=0)
#       3 print(dfs[3].shape)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
print(dfs[4].shape)
dfs[4] = dfs[4].drop(['MH40BG0869', 'MH40BG0841','MH40BG0842','MH40BG2597','MH40BG1085','MH31EM0396','MH40BG2596','MH40BG7470','MH40BL3842','MH40BG1208','MH40BG1076','MH40BG1083','MH40BG3238','MH31EM0397','MH40BL3833','MH31EM0395','MH40BG1081','MH40BG1209','MH40BG1215','MH31EM0417','MH31EM0391','MH31FC0216','MH31FC0406','MH31FC0944','MH31FC0939','MH31FC0947','MH31EM0392','MH31EM0389','MH31FC0382','MH31FC0424','MH31FC0942','MH31FC0945','MH31FC0946','MH31FC0377','MH40BG1543','MH40BG1551','MH40BG2981','MH40BG1548','MH40BG3460','MH31EM0409','MH40BG1161','MH40BG2980','MH31EM0423','MH40BG1549','MH31EM0425','MH40AT0182','MH40Y6893','MH40AT0460','MH40Y6891','MH40Y6895','MH40BG2008'], axis=0)
print(dfs[4].shape)
# Out:
# (10580, 10)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-8e419e57dffd> in <cell line: 2>()
#       1 print(dfs[4].shape)
# ----> 2 dfs[4] = dfs[4].drop(['MH40BG0869', 'MH40BG0841','MH40BG0842','MH40BG2597','MH40BG1085','MH31EM0396','MH40BG2596','MH40BG7470','MH40BL3842','MH40BG1208','MH40BG1076','MH40BG1083','MH40BG3238','MH31EM0397','MH40BL3833','MH31EM0395','MH40BG1081','MH40BG1209','MH40BG1215','MH31EM0417','MH31EM0391','MH31FC0216','MH31FC0406','MH31FC0944','MH31FC0939','MH31FC0947','MH31EM0392','MH31EM0389','MH31FC0382','MH31FC0424','MH31FC0942','MH31FC0945','MH31FC0946','MH31FC0377','MH40BG1543','MH40BG1551','MH40BG2981','MH40BG1548'...
#       3 print(dfs[4].shape)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
# ...

# %%
combined_df = pd.concat([dfs[1], dfs[2], dfs[3],dfs[4]], axis=0, ignore_index=True)

# %%
# data[data['groupName'] == 'Tra'].index

# %%
count_lists = ['distance', 'me_fcw_count','me_hmw_count', 'me_pcw_count', 'me_lldw_count',	'me_rldw_count']
data_ = data.groupby(['VehicleNum','groupName', 'driverName'])[count_lists].sum().reset_index()
print(data_.shape)
data_.head()

# %%
# rem_col = ['MH31EM0391']

# data_ = data_[~data_['VehicleNum'].isin(rem_col)]
# print(data_.shape)

# %%
# with pd.ExcelWriter('output.xlsx') as writer:
#   for g_name, g_data in data_.groupby('groupName'):
#     g_data.to_excel(writer, sheet_name=g_name, index=False)

# %%
print(data['groupName'].value_counts(),'\n')
print(data_['groupName'].value_counts())

# %%
name_list = data_['groupName'].unique()
print(name_list)

for g_value in name_list:

  g_df = data_[data_['groupName'] == g_value]
  f_name = f"group_{g_value}.xlsx"
  g_df.to_excel(f_name, index=False)

# %%
name_ = 'Hansa-School-Bus-Fleet'

group_df = data[data['groupName'] == 'name_']
group_df.head()

# %%
# Only for Hansa-School-Bus-Fleet

gp_df = data[data['groupName'] == 'Hansa-School-Bus-Fleet']

count_lists = ['distance', 'me_fcw_count','me_hmw_count', 'me_lldw_count',	'me_pcw_count',	'me_rldw_count']
gp_df = gp_df.groupby('VehicleNum')[count_lists].sum().reset_index()

gp_df.head()

# %%
gp_df.to_excel("group_Hansa-School-Bus-Fleet.xlsx")
